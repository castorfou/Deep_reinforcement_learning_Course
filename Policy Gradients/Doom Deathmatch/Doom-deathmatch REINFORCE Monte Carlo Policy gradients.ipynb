# %% [markdown]
# # Doom-Deathmatch: REINFORCE Monte Carlo Policy gradients 🕹️

# %% [markdown]
# In this notebook we'll implement an agent <b>that try to survive in Doom environment by killing all monster that are spawned in the map.</b> <br>
# Our agent playing after 206 epochs of 1000 batch_size (2h of training with CPU), **we can see that our agent needs much more training but he begins to have rational actions.**
# <img src="assets/doom.gif" alt="Doom Deathmatch" />

# %% [markdown]
# # This is a notebook from [Deep Reinforcement Learning Course with Tensorflow](https://simoninithomas.github.io/Deep_reinforcement_learning_Course/)
# <img src="https://raw.githubusercontent.com/simoninithomas/Deep_reinforcement_learning_Course/master/docs/assets/img/DRLC%20Environments.png" alt="Deep Reinforcement Course"/>
# <br>
# <p>  Deep Reinforcement Learning Course is a free series of articles and videos tutorials 🆕 about Deep Reinforcement Learning, where **we'll learn the main algorithms (Q-learning, Deep Q Nets, Dueling Deep Q Nets, Policy Gradients, A2C, Proximal Policy Gradients…), and how to implement them with Tensorflow.**
# <br><br>
#
# 📜The articles explain the architectures from the big picture to the mathematical details behind them.
# <br>
# 📹 The videos explain how to build the agents with Tensorflow </b></p>
# <br>
# This course will give you a **solid foundation for understanding and implementing the future state of the art algorithms**. And, you'll build a strong professional portfolio by creating **agents that learn to play awesome environments**: Doom© 👹, Space invaders 👾, Outrun, Sonic the Hedgehog©, Michael Jackson’s Moonwalker, agents that will be able to navigate in 3D environments with DeepMindLab (Quake) and able to walk with Mujoco.
# <br><br>
# </p>
#
# ## 📚 The complete [Syllabus HERE](https://simoninithomas.github.io/Deep_reinforcement_learning_Course/)
#
#
# ## Any questions 👨‍💻
# <p> If you have any questions, feel free to ask me: </p>
# <p> 📧: <a href="mailto:hello@simoninithomas.com">hello@simoninithomas.com</a>  </p>
# <p> Github: https://github.com/simoninithomas/Deep_reinforcement_learning_Course </p>
# <p> 🌐 : https://simoninithomas.github.io/Deep_reinforcement_learning_Course/ </p>
# <p> Twitter: <a href="https://twitter.com/ThomasSimonini">@ThomasSimonini</a> </p>
# <p> Don't forget to <b> follow me on <a href="https://twitter.com/ThomasSimonini">twitter</a>, <a href="https://github.com/simoninithomas/Deep_reinforcement_learning_Course">github</a> and <a href="https://medium.com/@thomassimonini">Medium</a> to be alerted of the new articles that I publish </b></p>
#
# ## How to help  🙌
# 3 ways:
# - **Clap our articles and like our videos a lot**:Clapping in Medium means that you really like our articles. And the more claps we have, the more our article is shared Liking our videos help them to be much more visible to the deep learning community.
# - **Share and speak about our articles and videos**: By sharing our articles and videos you help us to spread the word.
# - **Improve our notebooks**: if you found a bug or **a better implementation** you can send a pull request.
# <br>
#
# ## Important note 🤔
# <b> You can run it on your computer but it's better to run it on GPU based services</b>, personally I use Microsoft Azure and their Deep Learning Virtual Machine (they offer 170$)
# https://azuremarketplace.microsoft.com/en-us/marketplace/apps/microsoft-ads.dsvm-deep-learning
# <br>
# ⚠️ I don't have any business relations with them. I just loved their excellent customer service.
#
# If you have some troubles to use Microsoft Azure follow the explainations of this excellent article here (without last the part fast.ai): https://medium.com/@manikantayadunanda/setting-up-deeplearning-machine-and-fast-ai-on-azure-a22eb6bd6429

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving on the notebook **you need to understand**:
# - The foundations of Reinforcement learning (MC, TD, Rewards hypothesis...) [Article](https://medium.freecodecamp.org/an-introduction-to-reinforcement-learning-4339519de419)
# - Policy gradients [Article](https://medium.freecodecamp.org/an-introduction-to-policy-gradients-with-cartpole-and-doom-495b5ef2207f)
# - We made a [tutorial video](https://youtu.be/wLTQRuizVyE) where we implement a Policy Gradient agent with Tensorflow that learns to play Doom 👹🔫 in a Deathmatch environment.

# %%
from IPython.display import HTML
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/wLTQRuizVyE?showinfo=0" frameborder="0" allow="autoplay; encrypted-media" allowfullscreen></iframe>')
# Out:
# /home/explore/miniconda3/envs/drl_simonini/lib/python3.7/site-packages/IPython/core/display.py:717: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="560" height="315" src="https://www.youtube.com/embed/wLTQRuizVyE?showinfo=0" frameborder="0" allow="autoplay; encrypted-media" allowfullscreen></iframe>

# %% [markdown]
# ## Step 1: Import the libraries 📚

# %%
import tensorflow as tf      # Deep Learning library
import numpy as np           # Handle matrices
from vizdoom import *        # Doom Environment
import random                # Handling random number generation
import time                  # Handling time calculation
from skimage import transform# Help us to preprocess the frames

from collections import deque# Ordered collection with ends
import matplotlib.pyplot as plt # Display graphs

import warnings # This ignore all the warning messages that are normally printed during the training because of skiimage
warnings.filterwarnings('ignore')

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth=True

# %% [markdown]
# ## Step 2: Create our environment 🎮
# - Now that we imported the libraries/dependencies, we will create our environment.
# - Doom environment takes:
#     - A `configuration file` that **handle all the options** (size of the frame, possible actions...)
#     - A `scenario file`: that **generates the correct scenario** (in our case basic **but you're invited to try other scenarios**).
# - Note: We have 3 possible actions turn left, turn right, shoot (attack) `[[0,0,1], [1,0,0], [0,1,0]]` so we don't need to do one hot encoding (thanks to <a href="https://stackoverflow.com/users/2237916/silgon">silgon</a> for figuring out.
#
# ### Our environment
# <img src="https://simoninithomas.github.io/Deep_reinforcement_learning_Course/assets/img/video%20projects/vizdoomdeathmatch.png" style="max-width:500px;" alt="Doom health"/>
#
# - The purpose of this scenario is **to teach the agent that killing the monsters is GOOD and when monsters kill you is BAD**.
# - In addition, **wasting amunition is not very good either**.
# - Agent is rewarded only for killing monsters so he has to figure out the rest for himself.
# <br><br>
# - Map is a large circle. Player is spawned in the exact center. 5 melee-only, monsters are spawned along the wall.
# - **Monsters are killed after a single shot.**
# - After dying each monster is **respawned after some time**.
# - Episode ends when the player dies (**it's inevitable becuse of limitted ammo**).
# <br><br>
# REWARDS:
# - +1 for killing a monster
# <br><br>
# - 3 available buttons: turn left, turn right, shoot (attack)
# - death penalty = 1

# %%
"""
Here we create our environment
"""
def create_environment():
    game = DoomGame()
    
    # Load the correct configuration
    game.load_config("defend_the_center.cfg")
    
    # Load the correct scenario (in our case defend_the_center scenario)
    game.set_doom_scenario_path("defend_the_center.wad")
    
    game.init()
    
    # Here our possible actions
    # [[1,0,0],[0,1,0],[0,0,1]]
    possible_actions  = np.identity(3,dtype=int).tolist()
    
    return game, possible_actions

# %%
game, possible_actions = create_environment()

# %% [markdown]
# ## Step 3: Define the preprocessing functions ⚙️
# ### preprocess_frame 🖼️
# Preprocessing is an important step, <b>because we want to reduce the complexity of our states to reduce the computation time needed for training.</b>
# <br><br>
# Our steps:
# - Grayscale each of our frames (because <b> color does not add important information </b>). But this is already done by the config file.
# - Crop the screen (in our case we remove the roof because it contains no information)
# - We normalize pixel values
# - Finally we resize the preprocessed frame

# %%
"""
    preprocess_frame:
    Take a frame.
    Resize it.
        __________________
        |                 |
        |                 |
        |                 |
        |                 |
        |_________________|
        
        to
        _____________
        |            |
        |            |
        |            |
        |____________|
    Normalize it.
    
    return preprocessed_frame
    
    """
def preprocess_frame(frame):
    # Greyscale frame already done in our vizdoom config
    # x = np.mean(frame,-1)
    
    # Crop the screen (remove the roof because it contains no information)
    # [Up: Down, Left: right]
    cropped_frame = frame[40:,:]
    
    # Normalize Pixel Values
    normalized_frame = cropped_frame/255.0
    
    # Resize
    preprocessed_frame = transform.resize(normalized_frame, [100,160])
    
    return preprocessed_frame

# %% [markdown]
# ### stack_frames
# 👏 This part was made possible thanks to help of <a href="https://github.com/Miffyli">Anssi</a><br>
#
# As explained in this really <a href="https://danieltakeshi.github.io/2016/11/25/frame-skipping-and-preprocessing-for-deep-q-networks-on-atari-2600-games/">  good article </a> we stack frames.
#
# Stacking frames is really important because it helps us to **give have a sense of motion to our Neural Network.**
#
# - First we preprocess frame
# - Then we append the frame to the deque that automatically **removes the oldest frame**
# - Finally we **build the stacked state**
#
# This is how work stack:
# - For the first frame, we feed 4 frames
# - At each timestep, **we add the new frame to deque and then we stack them to form a new stacked frame**
# - And so on
# <img src="https://raw.githubusercontent.com/simoninithomas/Deep_reinforcement_learning_Course/master/DQN/Space%20Invaders/assets/stack_frames.png" alt="stack">
# - If we're done, **we create a new stack with 4 new frames (because we are in a new episode)**.

# %%
stack_size = 4 # We stack 4 frames

# Initialize deque with zero-images one array for each image
stacked_frames  =  deque([np.zeros((100,160), dtype=np.int) for i in range(stack_size)], maxlen=4) 

def stack_frames(stacked_frames, state, is_new_episode):
    # Preprocess frame
    frame = preprocess_frame(state)
    
    if is_new_episode:
        # Clear our stacked_frames
        stacked_frames = deque([np.zeros((100,160), dtype=np.int) for i in range(stack_size)], maxlen=4)
        
        # Because we're in a new episode, copy the same frame 4x
        stacked_frames.append(frame)
        stacked_frames.append(frame)
        stacked_frames.append(frame)
        stacked_frames.append(frame)
        
        # Stack the frames
        stacked_state = np.stack(stacked_frames, axis=2)

    else:
        # Append frame to deque, automatically removes the oldest frame
        stacked_frames.append(frame)

        # Build the stacked state (first dimension specifies different frames)
        stacked_state = np.stack(stacked_frames, axis=2) 
    
    return stacked_state, stacked_frames

# %% [markdown]
# ### discount_and_normalize_rewards 💰
# This function is important, because we are in a Monte Carlo situation. <br>
#
# We need to **discount the rewards at the end of the episode**. This function takes, the reward discount it, and **then normalize them** (to avoid a big variability in rewards).

# %%
def discount_and_normalize_rewards(episode_rewards):
    discounted_episode_rewards = np.zeros_like(episode_rewards)
    cumulative = 0.0
    for i in reversed(range(len(episode_rewards))):
        cumulative = cumulative * gamma + episode_rewards[i]
        discounted_episode_rewards[i] = cumulative
    
    mean = np.mean(discounted_episode_rewards)
    std = np.std(discounted_episode_rewards)
    discounted_episode_rewards = (discounted_episode_rewards - mean) / (std)

    return discounted_episode_rewards

# %% [markdown]
# ## Step 4: Set up our hyperparameters ⚗️
# In this part we'll set up our different hyperparameters. But when you implement a Neural Network by yourself you will **not implement hyperparamaters at once but progressively**.
#
# - First, you begin by defining the neural networks hyperparameters when you implement the model.
# - Then, you'll add the training hyperparameters when you implement the training algorithm.

# %%
### ENVIRONMENT HYPERPARAMETERS
state_size = [100,160,4] # Our input is a stack of 4 frames hence 100x160x4 (Width, height, channels) 
action_size = game.get_available_buttons_size() # 3 possible actions: turn left, turn right, shoot
stack_size = 4 # Defines how many frames are stacked together

## TRAINING HYPERPARAMETERS
learning_rate = 0.0001 
num_epochs = 5000  # Total epochs for training 

batch_size = 1000 # Each 1 is a timestep (NOT AN EPISODE) # YOU CAN CHANGE TO 5000 if you have GPU
gamma = 0.99 # Discounting rate

### MODIFY THIS TO FALSE IF YOU JUST WANT TO SEE THE TRAINED AGENT
training = True

# %% [markdown]
# Quick note: Policy gradient methods like reinforce **are on-policy method which can not be updated from experience replay.**

# %% [markdown]
# ## Step 5: Create our Policy Gradient Neural Network model 🧠
#
# This is our Policy Gradient model:
# - We take a stack of 4 frames as input
# - It passes through 3 convnets
# - Then it is flatened
# - Finally it passes through 2 FC layers
# - It outputs a probability distribution over actions

# %% [markdown]
# <img src="assets/doomPG1.png" alt="Doom PG"/>

# %%
class PGNetwork:
    def __init__(self, state_size, action_size, learning_rate, name='PGNetwork'):
        self.state_size = state_size
        self.action_size = action_size
        self.learning_rate = learning_rate
        
        with tf.variable_scope(name):
            with tf.name_scope("inputs"):
                # We create the placeholders
                # *state_size means that we take each elements of state_size in tuple hence is like if we wrote
                # [None, 84, 84, 4]
                self.inputs_= tf.placeholder(tf.float32, [None, *state_size], name="inputs_")
                self.actions = tf.placeholder(tf.int32, [None, action_size], name="actions")
                self.discounted_episode_rewards_ = tf.placeholder(tf.float32, [None, ], name="discounted_episode_rewards_")
            
                
                # Add this placeholder for having this variable in tensorboard
                self.mean_reward_ = tf.placeholder(tf.float32, name="mean_reward")
                
            with tf.name_scope("conv1"):
                """
                First convnet:
                CNN
                BatchNormalization
                ELU
                """
                # Input is 84x84x4
                self.conv1 = tf.layers.conv2d(inputs = self.inputs_,
                                             filters = 32,
                                             kernel_size = [8,8],
                                             strides = [4,4],
                                             padding = "VALID",
                                              kernel_initializer=tf.contrib.layers.xavier_initializer_conv2d(),
                                             name = "conv1")

                self.conv1_batchnorm = tf.layers.batch_normalization(self.conv1,
                                                       training = True,
                                                       epsilon = 1e-5,
                                                         name = 'batch_norm1')

                self.conv1_out = tf.nn.elu(self.conv1_batchnorm, name="conv1_out")
                ## --> [20, 20, 32]
            
            with tf.name_scope("conv2"):
                """
                Second convnet:
                CNN
                BatchNormalization
                ELU
                """
                self.conv2 = tf.layers.conv2d(inputs = self.conv1_out,
                                     filters = 64,
                                     kernel_size = [4,4],
                                     strides = [2,2],
                                     padding = "VALID",
                                    kernel_initializer=tf.contrib.layers.xavier_initializer_conv2d(),
                                     name = "conv2")

                self.conv2_batchnorm = tf.layers.batch_normalization(self.conv2,
                                                       training = True,
                                                       epsilon = 1e-5,
                                                         name = 'batch_norm2')

                self.conv2_out = tf.nn.elu(self.conv2_batchnorm, name="conv2_out")
                ## --> [9, 9, 64]
            
            with tf.name_scope("conv3"):
                """
                Third convnet:
                CNN
                BatchNormalization
                ELU
                """
                self.conv3 = tf.layers.conv2d(inputs = self.conv2_out,
                                     filters = 128,
                                     kernel_size = [4,4],
                                     strides = [2,2],
                                     padding = "VALID",
                                    kernel_initializer=tf.contrib.layers.xavier_initializer_conv2d(),
                                     name = "conv3")

                self.conv3_batchnorm = tf.layers.batch_normalization(self.conv3,
                                                       training = True,
                                                       epsilon = 1e-5,
                                                         name = 'batch_norm3')

                self.conv3_out = tf.nn.elu(self.conv3_batchnorm, name="conv3_out")
                ## --> [3, 3, 128]
            
            with tf.name_scope("flatten"):
                self.flatten = tf.layers.flatten(self.conv3_out)
                ## --> [1152]
            
            with tf.name_scope("fc1"):
                self.fc = tf.layers.dense(inputs = self.flatten,
                                      units = 512,
                                      activation = tf.nn.elu,
                                           kernel_initializer=tf.contrib.layers.xavier_initializer(),
                                    name="fc1")
            
            with tf.name_scope("logits"):
                self.logits = tf.layers.dense(inputs = self.fc, 
                                               kernel_initializer=tf.contrib.layers.xavier_initializer(),
                                              units = 3, 
                                            activation=None)
            
            with tf.name_scope("softmax"):
                self.action_distribution = tf.nn.softmax(self.logits)
                

            with tf.name_scope("loss"):
                # tf.nn.softmax_cross_entropy_with_logits computes the cross entropy of the result after applying the softmax function
                # If you have single-class labels, where an object can only belong to one class, you might now consider using 
                # tf.nn.sparse_softmax_cross_entropy_with_logits so that you don't have to convert your labels to a dense one-hot array. 
                self.neg_log_prob = tf.nn.softmax_cross_entropy_with_logits_v2(logits = self.logits, labels = self.actions)
                self.loss = tf.reduce_mean(self.neg_log_prob * self.discounted_episode_rewards_) 
        
    
            with tf.name_scope("train"):
                self.train_opt = tf.train.RMSPropOptimizer(self.learning_rate).minimize(self.loss)

# %%
# Reset the graph
tf.reset_default_graph()

# Instantiate the PGNetwork
PGNetwork = PGNetwork(state_size, action_size, learning_rate)

# Initialize Session
# sess = tf.Session()
sess = tf.Session(config=config)
init = tf.global_variables_initializer()
sess.run(init)
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From <ipython-input-10-6c75c112285e>:34: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From /home/explore/miniconda3/envs/drl_simonini/lib/python3.7/site-packages/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From <ipython-input-10-6c75c112285e>:39: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.BatchNormalization instead.  In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.batch_normalization` documentation).
# WARNING:tensorflow:From <ipython-input-10-6c75c112285e>:91: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From <ipython-input-10-6c75c112285e>:99: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /home/explore/miniconda3/envs/drl_simonini/lib/python3.7/site-packages/tensorflow_core/python/training/rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %% [markdown]
# ## Step 6: Set up Tensorboard 📊
# For more information about tensorboard, please watch this <a href="https://www.youtube.com/embed/eBbEDRsCmv4">excellent 30min tutorial</a> <br><br>
# To launch tensorboard : `tensorboard --logdir=./tensorboard/policy_gradients/1`

# %%
# Setup TensorBoard Writer
writer = tf.summary.FileWriter("./tensorboard/policy_gradients/1")

## Losses
tf.summary.scalar("Loss", PGNetwork.loss)

## Reward mean
tf.summary.scalar("Reward_mean", PGNetwork.mean_reward_ )

write_op = tf.summary.merge_all()

# %% [markdown]
# ## Step 7: Train our Agent 🏃‍♂️

# %% [markdown]
# Here we'll create batches.<br>
# These batches contains episodes **(their number depends on how many rewards we collect**: for instance if we have episodes with only 10 rewards we can put batch_size/10 episodes
# <br>
# * Make a batch
#     * For each step:
#         * Choose action a
#         * Perform action a
#         * Store s, a, r
#         * **If** done:
#             * Calculate sum reward
#             * Calculate gamma Gt

# %%
def make_batch(batch_size, stacked_frames):
    # Initialize lists: states, actions, rewards_of_episode, rewards_of_batch, discounted_rewards
    states, actions, rewards_of_episode, rewards_of_batch, discounted_rewards = [], [], [], [], []
    
    # Reward of batch is also a trick to keep track of how many timestep we made.
    # We use to to verify at the end of each episode if > batch_size or not.
    
    # Keep track of how many episodes in our batch (useful when we'll need to calculate the average reward per episode)
    episode_num  = 1
    
    # Launch a new episode
    game.new_episode()
        
    # Get a new state
    state = game.get_state().screen_buffer
    state, stacked_frames = stack_frames(stacked_frames, state, True)

    while True:
        # Run State Through Policy & Calculate Action
        action_probability_distribution = sess.run(PGNetwork.action_distribution, 
                                                   feed_dict={PGNetwork.inputs_: state.reshape(1, *state_size)})
        
        # REMEMBER THAT WE ARE IN A STOCHASTIC POLICY SO WE DON'T ALWAYS TAKE THE ACTION WITH THE HIGHEST PROBABILITY
        # (For instance if the action with the best probability for state S is a1 with 70% chances, there is
        #30% chance that we take action a2)
        action = np.random.choice(range(action_probability_distribution.shape[1]), 
                                  p=action_probability_distribution.ravel())  # select action w.r.t the actions prob
        action = possible_actions[action]

        # Perform action
        reward = game.make_action(action)
        done = game.is_episode_finished()

        # Store results
        states.append(state)
        actions.append(action)
        rewards_of_episode.append(reward)
        
        if done:
            # The episode ends so no next state
            next_state = np.zeros((100, 160), dtype=np.int)
            next_state, stacked_frames = stack_frames(stacked_frames, next_state, False)
            
            # Append the rewards_of_batch to reward_of_episode
            rewards_of_batch.append(rewards_of_episode)
            
            # Calculate gamma Gt
            discounted_rewards.append(discount_and_normalize_rewards(rewards_of_episode))
           
            # If the number of rewards_of_batch > batch_size stop the minibatch creation
            # (Because we have sufficient number of episode mb)
            # Remember that we put this condition here, because we want entire episode (Monte Carlo)
            # so we can't check that condition for each step but only if an episode is finished
            if len(np.concatenate(rewards_of_batch)) > batch_size:
                break
                
            # Reset the transition stores
            rewards_of_episode = []
            
            # Add episode
            episode_num += 1
            
            # Start a new episode
            game.new_episode()

            # First we need a state
            state = game.get_state().screen_buffer

            # Stack the frames
            state, stacked_frames = stack_frames(stacked_frames, state, True)
         
        else:
            # If not done, the next_state become the current state
            next_state = game.get_state().screen_buffer
            next_state, stacked_frames = stack_frames(stacked_frames, next_state, False)
            state = next_state
                         
    return np.stack(np.array(states)), np.stack(np.array(actions)), np.concatenate(rewards_of_batch), np.concatenate(discounted_rewards), episode_num

# %% [markdown]
# * Create the Neural Network
# * Initialize the weights
# * Init the environment
# * maxReward = 0 # Keep track of maximum reward
# * **For** epochs in range(num_epochs):
#     * Get batches
#     * Optimize

# %%
# Keep track of all rewards total for each batch
allRewards = []

total_rewards = 0
maximumRewardRecorded = 0
mean_reward_total = []
epoch = 1
average_reward = []

# Saver
saver = tf.train.Saver()

if training:
    # Load the model
    #saver.restore(sess, "./models/model.ckpt")

    while epoch < num_epochs + 1:
        # Gather training data
        states_mb, actions_mb, rewards_of_batch, discounted_rewards_mb, nb_episodes_mb = make_batch(batch_size, stacked_frames)

        ### These part is used for analytics
        # Calculate the total reward ot the batch
        total_reward_of_that_batch = np.sum(rewards_of_batch)
        allRewards.append(total_reward_of_that_batch)

        # Calculate the mean reward of the batch
        # Total rewards of batch / nb episodes in that batch
        mean_reward_of_that_batch = np.divide(total_reward_of_that_batch, nb_episodes_mb)
        mean_reward_total.append(mean_reward_of_that_batch)

        # Calculate the average reward of all training
        # mean_reward_of_that_batch / epoch
        average_reward_of_all_training = np.divide(np.sum(mean_reward_total), epoch)

        # Calculate maximum reward recorded 
        maximumRewardRecorded = np.amax(allRewards)

        print("==========================================")
        print("Epoch: ", epoch, "/", num_epochs)
        print("-----------")
        print("Number of training episodes: {}".format(nb_episodes_mb))
        print("Total reward: {}".format(total_reward_of_that_batch, nb_episodes_mb))
        print("Mean Reward of that batch {}".format(mean_reward_of_that_batch))
        print("Average Reward of all training: {}".format(average_reward_of_all_training))
        print("Max reward for a batch so far: {}".format(maximumRewardRecorded))

        # Feedforward, gradient and backpropagation
        loss_, _ = sess.run([PGNetwork.loss, PGNetwork.train_opt], feed_dict={PGNetwork.inputs_: states_mb.reshape((len(states_mb), 100,160,4)),
                                                            PGNetwork.actions: actions_mb,
                                                                     PGNetwork.discounted_episode_rewards_: discounted_rewards_mb 
                                                                    })

        print("Training Loss: {}".format(loss_))

        # Write TF Summaries
        summary = sess.run(write_op, feed_dict={PGNetwork.inputs_: states_mb.reshape((len(states_mb), 100,160,4)),
                                                            PGNetwork.actions: actions_mb,
                                                                     PGNetwork.discounted_episode_rewards_: discounted_rewards_mb,
                                                                    PGNetwork.mean_reward_: mean_reward_of_that_batch
                                                                    })

        #summary = sess.run(write_op, feed_dict={x: s_.reshape(len(s_),84,84,1), y:a_, d_r: d_r_, r: r_, n: n_})
        writer.add_summary(summary, epoch)
        writer.flush()

        # Save Model
        if epoch % 10 == 0:
            saver.save(sess, "./models/model.ckpt")
            print("Model saved")
        epoch += 1
# Out:
# ==========================================
# Epoch:  1 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 1.0
# Max reward for a batch so far: 3.0
# Training Loss: 0.047046106308698654
# ==========================================
# Epoch:  2 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -2.0
# Mean Reward of that batch -0.5
# Average Reward of all training: 0.25
# Max reward for a batch so far: 3.0
# Training Loss: 0.001062610186636448
# ==========================================
# Epoch:  3 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 0.25
# Max reward for a batch so far: 3.0
# Training Loss: -0.005793360993266106
# ==========================================
# Epoch:  4 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 0.4375
# Max reward for a batch so far: 3.0
# Training Loss: -0.0016468929825350642
# ==========================================
# Epoch:  5 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 0.4
# Max reward for a batch so far: 3.0
# Training Loss: 0.014690482057631016
# ==========================================
# Epoch:  6 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.3333333333333333
# Max reward for a batch so far: 3.0
# Training Loss: 0.0005595656111836433
# ==========================================
# Epoch:  7 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 1.0
# Mean Reward of that batch 0.3333333333333333
# Average Reward of all training: 0.33333333333333337
# Max reward for a batch so far: 3.0
# Training Loss: 0.03522440418601036
# ==========================================
# Epoch:  8 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.29166666666666663
# Max reward for a batch so far: 3.0
# Training Loss: -0.00236371997743845
# ==========================================
# Epoch:  9 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.25925925925925924
# Max reward for a batch so far: 3.0
# Training Loss: 0.0020418833009898663
# ==========================================
# Epoch:  10 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -2.0
# Mean Reward of that batch -0.5
# Average Reward of all training: 0.1833333333333333
# Max reward for a batch so far: 3.0
# Training Loss: -0.0075284456834197044
# Model saved
# ==========================================
# Epoch:  11 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 0.18939393939393936
# Max reward for a batch so far: 3.0
# Training Loss: -0.0030558276921510696
# ==========================================
# Epoch:  12 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.17361111111111108
# Max reward for a batch so far: 3.0
# Training Loss: 0.0011048116721212864
# ==========================================
# Epoch:  13 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 0.17948717948717946
# Max reward for a batch so far: 3.0
# Training Loss: 0.0296789538115263
# ==========================================
# Epoch:  14 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 2.0
# Mean Reward of that batch 0.5
# Average Reward of all training: 0.20238095238095236
# Max reward for a batch so far: 3.0
# Training Loss: -0.009357543662190437
# ==========================================
# Epoch:  15 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 0.20555555555555555
# Max reward for a batch so far: 3.0
# Training Loss: 0.04339888319373131
# ==========================================
# Epoch:  16 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 0.20833333333333331
# Max reward for a batch so far: 3.0
# Training Loss: 0.03312687575817108
# ==========================================
# Epoch:  17 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -4.0
# Mean Reward of that batch -1.0
# Average Reward of all training: 0.1372549019607843
# Max reward for a batch so far: 3.0
# Training Loss: 0.003518694546073675
# ==========================================
# Epoch:  18 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -2.0
# Mean Reward of that batch -0.5
# Average Reward of all training: 0.10185185185185183
# Max reward for a batch so far: 3.0
# Training Loss: 0.01913021318614483
# ==========================================
# Epoch:  19 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -1.0
# Mean Reward of that batch -0.25
# Average Reward of all training: 0.08333333333333331
# Max reward for a batch so far: 3.0
# Training Loss: 0.027277443557977676
# ==========================================
# Epoch:  20 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.07916666666666665
# Max reward for a batch so far: 3.0
# Training Loss: 0.00465365732088685
# Model saved
# ==========================================
# Epoch:  21 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -1.0
# Mean Reward of that batch -0.25
# Average Reward of all training: 0.06349206349206347
# Max reward for a batch so far: 3.0
# Training Loss: -0.0031628732103854418
# ==========================================
# Epoch:  22 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -1.0
# Mean Reward of that batch -0.25
# Average Reward of all training: 0.049242424242424226
# Max reward for a batch so far: 3.0
# Training Loss: 0.01766023598611355
# ==========================================
# Epoch:  23 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 0.05797101449275361
# Max reward for a batch so far: 3.0
# Training Loss: 0.027391880750656128
# ==========================================
# Epoch:  24 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 0.08333333333333333
# Max reward for a batch so far: 3.0
# Training Loss: 0.014549532905220985
# ==========================================
# Epoch:  25 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 0.09
# Max reward for a batch so far: 3.0
# Training Loss: -0.005111028905957937
# ==========================================
# Epoch:  26 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 0.11217948717948717
# Max reward for a batch so far: 3.0
# Training Loss: -0.0496324822306633
# ==========================================
# Epoch:  27 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -2.0
# Mean Reward of that batch -0.5
# Average Reward of all training: 0.08950617283950617
# Max reward for a batch so far: 3.0
# Training Loss: -0.007420723792165518
# ==========================================
# Epoch:  28 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 0.09523809523809523
# Max reward for a batch so far: 3.0
# Training Loss: 0.04518679901957512
# ==========================================
# Epoch:  29 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -1.0
# Mean Reward of that batch -0.25
# Average Reward of all training: 0.08333333333333333
# Max reward for a batch so far: 3.0
# Training Loss: -0.03490183874964714
# ==========================================
# Epoch:  30 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.08055555555555555
# Max reward for a batch so far: 3.0
# Training Loss: -0.01226204726845026
# Model saved
# ==========================================
# Epoch:  31 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 3.0
# Mean Reward of that batch 0.75
# Average Reward of all training: 0.1021505376344086
# Max reward for a batch so far: 3.0
# Training Loss: -0.011093340814113617
# ==========================================
# Epoch:  32 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 0.13020833333333334
# Max reward for a batch so far: 3.0
# Training Loss: -0.026485059410333633
# ==========================================
# Epoch:  33 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -3.0
# Mean Reward of that batch -0.75
# Average Reward of all training: 0.10353535353535355
# Max reward for a batch so far: 3.0
# Training Loss: -0.00838191993534565
# ==========================================
# Epoch:  34 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -2.0
# Mean Reward of that batch -0.5
# Average Reward of all training: 0.08578431372549021
# Max reward for a batch so far: 3.0
# Training Loss: -0.03237549588084221
# ==========================================
# Epoch:  35 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 2.0
# Mean Reward of that batch 0.5
# Average Reward of all training: 0.09761904761904763
# Max reward for a batch so far: 3.0
# Training Loss: 0.029354816302657127
# ==========================================
# Epoch:  36 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.09490740740740741
# Max reward for a batch so far: 3.0
# Training Loss: -0.0025852229446172714
# ==========================================
# Epoch:  37 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -2.0
# Mean Reward of that batch -0.5
# Average Reward of all training: 0.07882882882882884
# Max reward for a batch so far: 3.0
# Training Loss: -0.009309557266533375
# ==========================================
# Epoch:  38 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 2.0
# Mean Reward of that batch 0.5
# Average Reward of all training: 0.08991228070175439
# Max reward for a batch so far: 3.0
# Training Loss: 0.03765266761183739
# ==========================================
# Epoch:  39 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -2.0
# Mean Reward of that batch -0.5
# Average Reward of all training: 0.0747863247863248
# Max reward for a batch so far: 3.0
# Training Loss: -0.006726105231791735
# ==========================================
# Epoch:  40 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -2.0
# Mean Reward of that batch -0.5
# Average Reward of all training: 0.06041666666666666
# Max reward for a batch so far: 3.0
# Training Loss: 0.024496514350175858
# Model saved
# ==========================================
# Epoch:  41 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 0.06504065040650406
# Max reward for a batch so far: 3.0
# Training Loss: -0.010508066043257713
# ==========================================
# Epoch:  42 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 0.07936507936507936
# Max reward for a batch so far: 3.0
# Training Loss: -0.0356772355735302
# ==========================================
# Epoch:  43 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -1.0
# Mean Reward of that batch -0.25
# Average Reward of all training: 0.07170542635658914
# Max reward for a batch so far: 3.0
# Training Loss: -0.010117967613041401
# ==========================================
# Epoch:  44 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.07007575757575757
# Max reward for a batch so far: 3.0
# Training Loss: 1.1624313628999516e-05
# ==========================================
# Epoch:  45 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -1.0
# Mean Reward of that batch -0.25
# Average Reward of all training: 0.06296296296296296
# Max reward for a batch so far: 3.0
# Training Loss: -0.04202105477452278
# ==========================================
# Epoch:  46 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -1.0
# Mean Reward of that batch -0.25
# Average Reward of all training: 0.056159420289855065
# Max reward for a batch so far: 3.0
# Training Loss: 0.0200374573469162
# ==========================================
# Epoch:  47 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -2.0
# Mean Reward of that batch -0.5
# Average Reward of all training: 0.04432624113475177
# Max reward for a batch so far: 3.0
# Training Loss: 0.013019738718867302
# ==========================================
# Epoch:  48 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.04340277777777777
# Max reward for a batch so far: 3.0
# Training Loss: -0.011424772441387177
# ==========================================
# Epoch:  49 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 2.0
# Mean Reward of that batch 0.5
# Average Reward of all training: 0.052721088435374146
# Max reward for a batch so far: 3.0
# Training Loss: 0.028940053656697273
# ==========================================
# Epoch:  50 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -1.0
# Mean Reward of that batch -0.25
# Average Reward of all training: 0.04666666666666666
# Max reward for a batch so far: 3.0
# Training Loss: -0.007882854901254177
# Model saved
# ==========================================
# Epoch:  51 / 5000
# -----------
# Number of training episodes: 5
# Total reward: -1.0
# Mean Reward of that batch -0.2
# Average Reward of all training: 0.041830065359477114
# Max reward for a batch so far: 3.0
# Training Loss: -0.00128725147806108
# ==========================================
# Epoch:  52 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 0.053846153846153835
# Max reward for a batch so far: 3.0
# Training Loss: -0.0018140556057915092
# ==========================================
# Epoch:  53 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 0.07169811320754715
# Max reward for a batch so far: 3.0
# Training Loss: 0.04966110363602638
# ==========================================
# Epoch:  54 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 4.0
# Mean Reward of that batch 1.3333333333333333
# Average Reward of all training: 0.09506172839506172
# Max reward for a batch so far: 4.0
# Training Loss: 0.017475979402661324
# ==========================================
# Epoch:  55 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 0.09787878787878787
# Max reward for a batch so far: 4.0
# Training Loss: 0.0170443132519722
# ==========================================
# Epoch:  56 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -2.0
# Mean Reward of that batch -0.5
# Average Reward of all training: 0.08720238095238095
# Max reward for a batch so far: 4.0
# Training Loss: -0.01338590495288372
# ==========================================
# Epoch:  57 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 2.0
# Mean Reward of that batch 0.5
# Average Reward of all training: 0.09444444444444444
# Max reward for a batch so far: 4.0
# Training Loss: -0.014892634935677052
# ==========================================
# Epoch:  58 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.09281609195402298
# Max reward for a batch so far: 4.0
# Training Loss: -0.010773724876344204
# ==========================================
# Epoch:  59 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.09124293785310733
# Max reward for a batch so far: 4.0
# Training Loss: 0.015634499490261078
# ==========================================
# Epoch:  60 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.08972222222222222
# Max reward for a batch so far: 4.0
# Training Loss: -0.031094690784811974
# Model saved
# ==========================================
# Epoch:  61 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 0.10464480874316939
# Max reward for a batch so far: 4.0
# Training Loss: -0.015850700438022614
# ==========================================
# Epoch:  62 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.10295698924731182
# Max reward for a batch so far: 4.0
# Training Loss: -0.014209091663360596
# ==========================================
# Epoch:  63 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 0.10529100529100528
# Max reward for a batch so far: 4.0
# Training Loss: -0.00641603022813797
# ==========================================
# Epoch:  64 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 0.11406249999999998
# Max reward for a batch so far: 4.0
# Training Loss: 0.031040243804454803
# ==========================================
# Epoch:  65 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.11230769230769229
# Max reward for a batch so far: 4.0
# Training Loss: 0.028342384845018387
# ==========================================
# Epoch:  66 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 1.0
# Mean Reward of that batch 0.3333333333333333
# Average Reward of all training: 0.11565656565656564
# Max reward for a batch so far: 4.0
# Training Loss: 0.005077126901596785
# ==========================================
# Epoch:  67 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.11393034825870645
# Max reward for a batch so far: 4.0
# Training Loss: -0.006360653787851334
# ==========================================
# Epoch:  68 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 0.12696078431372548
# Max reward for a batch so far: 4.0
# Training Loss: -0.007305051200091839
# ==========================================
# Epoch:  69 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 1.0
# Mean Reward of that batch 0.3333333333333333
# Average Reward of all training: 0.12995169082125604
# Max reward for a batch so far: 4.0
# Training Loss: -0.0031506658997386694
# ==========================================
# Epoch:  70 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.1280952380952381
# Max reward for a batch so far: 4.0
# Training Loss: 0.004152895417064428
# Model saved
# ==========================================
# Epoch:  71 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -2.0
# Mean Reward of that batch -0.5
# Average Reward of all training: 0.11924882629107982
# Max reward for a batch so far: 4.0
# Training Loss: 0.006044099573045969
# ==========================================
# Epoch:  72 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -2.0
# Mean Reward of that batch -0.5
# Average Reward of all training: 0.11064814814814813
# Max reward for a batch so far: 4.0
# Training Loss: -0.019441410899162292
# ==========================================
# Epoch:  73 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 0.11826484018264839
# Max reward for a batch so far: 4.0
# Training Loss: -0.02531604655086994
# ==========================================
# Epoch:  74 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.11666666666666665
# Max reward for a batch so far: 4.0
# Training Loss: -0.047546327114105225
# ==========================================
# Epoch:  75 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.11511111111111111
# Max reward for a batch so far: 4.0
# Training Loss: -0.08981544524431229
# ==========================================
# Epoch:  76 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 0.12236842105263157
# Max reward for a batch so far: 4.0
# Training Loss: 0.006799276918172836
# ==========================================
# Epoch:  77 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -1.0
# Mean Reward of that batch -0.25
# Average Reward of all training: 0.11753246753246752
# Max reward for a batch so far: 4.0
# Training Loss: 0.04545006528496742
# ==========================================
# Epoch:  78 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 0.12884615384615383
# Max reward for a batch so far: 4.0
# Training Loss: 0.040120065212249756
# ==========================================
# Epoch:  79 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 0.13565400843881856
# Max reward for a batch so far: 4.0
# Training Loss: 0.0029356779996305704
# ==========================================
# Epoch:  80 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.13395833333333332
# Max reward for a batch so far: 4.0
# Training Loss: 0.032756343483924866
# Model saved
# ==========================================
# Epoch:  81 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 0.1353909465020576
# Max reward for a batch so far: 4.0
# Training Loss: 0.04742895066738129
# ==========================================
# Epoch:  82 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 0.13678861788617885
# Max reward for a batch so far: 4.0
# Training Loss: 0.025438133627176285
# ==========================================
# Epoch:  83 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -3.0
# Mean Reward of that batch -0.75
# Average Reward of all training: 0.1261044176706827
# Max reward for a batch so far: 4.0
# Training Loss: -0.025448618456721306
# ==========================================
# Epoch:  84 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 0.12757936507936507
# Max reward for a batch so far: 4.0
# Training Loss: -0.02823355793952942
# ==========================================
# Epoch:  85 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 2.0
# Mean Reward of that batch 0.5
# Average Reward of all training: 0.13196078431372546
# Max reward for a batch so far: 4.0
# Training Loss: 0.006984250620007515
# ==========================================
# Epoch:  86 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 0.1381782945736434
# Max reward for a batch so far: 4.0
# Training Loss: 0.002277204068377614
# ==========================================
# Epoch:  87 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 3.0
# Mean Reward of that batch 0.75
# Average Reward of all training: 0.14521072796934864
# Max reward for a batch so far: 4.0
# Training Loss: -0.03684459254145622
# ==========================================
# Epoch:  88 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 0.14640151515151514
# Max reward for a batch so far: 4.0
# Training Loss: -0.046023957431316376
# ==========================================
# Epoch:  89 / 5000
# -----------
# Number of training episodes: 5
# Total reward: -3.0
# Mean Reward of that batch -0.6
# Average Reward of all training: 0.13801498127340825
# Max reward for a batch so far: 4.0
# Training Loss: 0.002820471301674843
# ==========================================
# Epoch:  90 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.13648148148148148
# Max reward for a batch so far: 4.0
# Training Loss: 0.01760994829237461
# Model saved
# ==========================================
# Epoch:  91 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 2.0
# Mean Reward of that batch 0.5
# Average Reward of all training: 0.14047619047619048
# Max reward for a batch so far: 4.0
# Training Loss: -0.030251426622271538
# ==========================================
# Epoch:  92 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 4.0
# Mean Reward of that batch 1.3333333333333333
# Average Reward of all training: 0.15344202898550724
# Max reward for a batch so far: 4.0
# Training Loss: 0.04740983620285988
# ==========================================
# Epoch:  93 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 1.0
# Mean Reward of that batch 0.3333333333333333
# Average Reward of all training: 0.15537634408602152
# Max reward for a batch so far: 4.0
# Training Loss: -0.002203387441113591
# ==========================================
# Epoch:  94 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 1.0
# Mean Reward of that batch 0.3333333333333333
# Average Reward of all training: 0.1572695035460993
# Max reward for a batch so far: 4.0
# Training Loss: 0.02020733803510666
# ==========================================
# Epoch:  95 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 0.16263157894736843
# Max reward for a batch so far: 4.0
# Training Loss: -0.0036974954418838024
# ==========================================
# Epoch:  96 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -1.0
# Mean Reward of that batch -0.25
# Average Reward of all training: 0.15833333333333333
# Max reward for a batch so far: 4.0
# Training Loss: 0.020763220265507698
# ==========================================
# Epoch:  97 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 2.0
# Mean Reward of that batch 0.5
# Average Reward of all training: 0.16185567010309276
# Max reward for a batch so far: 4.0
# Training Loss: -0.0768359899520874
# ==========================================
# Epoch:  98 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 0.16700680272108845
# Max reward for a batch so far: 4.0
# Training Loss: -0.03662380948662758
# ==========================================
# Epoch:  99 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.1653198653198653
# Max reward for a batch so far: 4.0
# Training Loss: 0.03727373853325844
# ==========================================
# Epoch:  100 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 0.16616666666666668
# Max reward for a batch so far: 4.0
# Training Loss: 0.01345382072031498
# Model saved
# ==========================================
# Epoch:  101 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 3.0
# Mean Reward of that batch 0.75
# Average Reward of all training: 0.17194719471947195
# Max reward for a batch so far: 4.0
# Training Loss: 0.052534572780132294
# ==========================================
# Epoch:  102 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 0.1866013071895425
# Max reward for a batch so far: 5.0
# Training Loss: -0.0014261759351938963
# ==========================================
# Epoch:  103 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 0.2009708737864078
# Max reward for a batch so far: 5.0
# Training Loss: -0.00863194465637207
# ==========================================
# Epoch:  104 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 11.0
# Mean Reward of that batch 3.6666666666666665
# Average Reward of all training: 0.2342948717948718
# Max reward for a batch so far: 11.0
# Training Loss: -0.029570449143648148
# ==========================================
# Epoch:  105 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.23206349206349206
# Max reward for a batch so far: 11.0
# Training Loss: -0.04549665376543999
# ==========================================
# Epoch:  106 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.229874213836478
# Max reward for a batch so far: 11.0
# Training Loss: 0.04776835814118385
# ==========================================
# Epoch:  107 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 4.0
# Mean Reward of that batch 1.3333333333333333
# Average Reward of all training: 0.24018691588785046
# Max reward for a batch so far: 11.0
# Training Loss: -0.019710220396518707
# ==========================================
# Epoch:  108 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.23796296296296296
# Max reward for a batch so far: 11.0
# Training Loss: -0.0021924939937889576
# ==========================================
# Epoch:  109 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 2.0
# Mean Reward of that batch 0.5
# Average Reward of all training: 0.2403669724770642
# Max reward for a batch so far: 11.0
# Training Loss: 0.01779530569911003
# ==========================================
# Epoch:  110 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 0.24045454545454545
# Max reward for a batch so far: 11.0
# Training Loss: 0.044556811451911926
# Model saved
# ==========================================
# Epoch:  111 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 0.24054054054054053
# Max reward for a batch so far: 11.0
# Training Loss: 0.012703985907137394
# ==========================================
# Epoch:  112 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 2.0
# Mean Reward of that batch 0.5
# Average Reward of all training: 0.24285714285714285
# Max reward for a batch so far: 11.0
# Training Loss: 0.06731552630662918
# ==========================================
# Epoch:  113 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.2407079646017699
# Max reward for a batch so far: 11.0
# Training Loss: 0.032421428710222244
# ==========================================
# Epoch:  114 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 0.24078947368421053
# Max reward for a batch so far: 11.0
# Training Loss: 0.038515932857990265
# ==========================================
# Epoch:  115 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 0.2408695652173913
# Max reward for a batch so far: 11.0
# Training Loss: 0.07577573508024216
# ==========================================
# Epoch:  116 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 0.2589080459770115
# Max reward for a batch so far: 11.0
# Training Loss: 0.025688517838716507
# ==========================================
# Epoch:  117 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 0.2652421652421652
# Max reward for a batch so far: 11.0
# Training Loss: 0.03136897832155228
# ==========================================
# Epoch:  118 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 0.2827683615819209
# Max reward for a batch so far: 11.0
# Training Loss: -0.062167055904865265
# ==========================================
# Epoch:  119 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 10.0
# Mean Reward of that batch 3.3333333333333335
# Average Reward of all training: 0.30840336134453783
# Max reward for a batch so far: 11.0
# Training Loss: -0.039102356880903244
# ==========================================
# Epoch:  120 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 0.3252777777777778
# Max reward for a batch so far: 11.0
# Training Loss: -0.010215738788247108
# Model saved
# ==========================================
# Epoch:  121 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 0.3418732782369146
# Max reward for a batch so far: 11.0
# Training Loss: -0.041065800935029984
# ==========================================
# Epoch:  122 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -1.0
# Mean Reward of that batch -0.25
# Average Reward of all training: 0.33702185792349726
# Max reward for a batch so far: 11.0
# Training Loss: 0.055191949009895325
# ==========================================
# Epoch:  123 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 0.33631436314363145
# Max reward for a batch so far: 11.0
# Training Loss: 0.012814611196517944
# ==========================================
# Epoch:  124 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 0.3416666666666667
# Max reward for a batch so far: 11.0
# Training Loss: 0.03028421476483345
# ==========================================
# Epoch:  125 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.33893333333333336
# Max reward for a batch so far: 11.0
# Training Loss: -0.005130183883011341
# ==========================================
# Epoch:  126 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 11.0
# Mean Reward of that batch 5.5
# Average Reward of all training: 0.3798941798941799
# Max reward for a batch so far: 11.0
# Training Loss: 0.021342946216464043
# ==========================================
# Epoch:  127 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 15.0
# Mean Reward of that batch 5.0
# Average Reward of all training: 0.4162729658792651
# Max reward for a batch so far: 15.0
# Training Loss: -0.021631386131048203
# ==========================================
# Epoch:  128 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 0.42864583333333334
# Max reward for a batch so far: 15.0
# Training Loss: 0.01150783896446228
# ==========================================
# Epoch:  129 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 0.44599483204134366
# Max reward for a batch so far: 15.0
# Training Loss: -0.047217607498168945
# ==========================================
# Epoch:  130 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 8.0
# Mean Reward of that batch 4.0
# Average Reward of all training: 0.47333333333333333
# Max reward for a batch so far: 15.0
# Training Loss: 0.017994793131947517
# Model saved
# ==========================================
# Epoch:  131 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 10.0
# Mean Reward of that batch 5.0
# Average Reward of all training: 0.5078880407124682
# Max reward for a batch so far: 15.0
# Training Loss: -0.042375363409519196
# ==========================================
# Epoch:  132 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 0.5267676767676768
# Max reward for a batch so far: 15.0
# Training Loss: -0.08955670893192291
# ==========================================
# Epoch:  133 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 0.5403508771929824
# Max reward for a batch so far: 15.0
# Training Loss: -0.033079273998737335
# ==========================================
# Epoch:  134 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 0.5512437810945273
# Max reward for a batch so far: 15.0
# Training Loss: -0.019810987636446953
# ==========================================
# Epoch:  135 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 0.5619753086419753
# Max reward for a batch so far: 15.0
# Training Loss: -0.0198568906635046
# ==========================================
# Epoch:  136 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 0.5774509803921568
# Max reward for a batch so far: 15.0
# Training Loss: -0.0030268849804997444
# ==========================================
# Epoch:  137 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 0.5805352798053528
# Max reward for a batch so far: 15.0
# Training Loss: -0.022562414407730103
# ==========================================
# Epoch:  138 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 7.0
# Mean Reward of that batch 3.5
# Average Reward of all training: 0.6016908212560387
# Max reward for a batch so far: 15.0
# Training Loss: 0.015508496202528477
# ==========================================
# Epoch:  139 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.5973621103117506
# Max reward for a batch so far: 15.0
# Training Loss: 0.02948007360100746
# ==========================================
# Epoch:  140 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 0.6097619047619047
# Max reward for a batch so far: 15.0
# Training Loss: -0.012029179371893406
# Model saved
# ==========================================
# Epoch:  141 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 12.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 0.6267139479905437
# Max reward for a batch so far: 15.0
# Training Loss: -0.049625594168901443
# ==========================================
# Epoch:  142 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 0.634037558685446
# Max reward for a batch so far: 15.0
# Training Loss: -0.03291454538702965
# ==========================================
# Epoch:  143 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 10.0
# Mean Reward of that batch 3.3333333333333335
# Average Reward of all training: 0.6529137529137529
# Max reward for a batch so far: 15.0
# Training Loss: 0.03506896644830704
# ==========================================
# Epoch:  144 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 0.6668981481481482
# Max reward for a batch so far: 15.0
# Training Loss: 0.06638499349355698
# ==========================================
# Epoch:  145 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 4.0
# Mean Reward of that batch 1.3333333333333333
# Average Reward of all training: 0.6714942528735631
# Max reward for a batch so far: 15.0
# Training Loss: -0.001607162761501968
# ==========================================
# Epoch:  146 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 0.6874429223744292
# Max reward for a batch so far: 15.0
# Training Loss: 0.04047878086566925
# ==========================================
# Epoch:  147 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -2.0
# Mean Reward of that batch -0.5
# Average Reward of all training: 0.6793650793650793
# Max reward for a batch so far: 15.0
# Training Loss: 0.030704688280820847
# ==========================================
# Epoch:  148 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 0.6792792792792792
# Max reward for a batch so far: 15.0
# Training Loss: -0.0945950597524643
# ==========================================
# Epoch:  149 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 0.6903803131991051
# Max reward for a batch so far: 15.0
# Training Loss: -0.07620206475257874
# ==========================================
# Epoch:  150 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 0.6968888888888889
# Max reward for a batch so far: 15.0
# Training Loss: -0.050954632461071014
# Model saved
# ==========================================
# Epoch:  151 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.6922737306843267
# Max reward for a batch so far: 15.0
# Training Loss: -0.034464288502931595
# ==========================================
# Epoch:  152 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.6877192982456141
# Max reward for a batch so far: 15.0
# Training Loss: 0.07969657331705093
# ==========================================
# Epoch:  153 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -4.0
# Mean Reward of that batch -1.0
# Average Reward of all training: 0.6766884531590414
# Max reward for a batch so far: 15.0
# Training Loss: -0.0015928366919979453
# ==========================================
# Epoch:  154 / 5000
# -----------
# Number of training episodes: 3
# Total reward: -1.0
# Mean Reward of that batch -0.3333333333333333
# Average Reward of all training: 0.6701298701298701
# Max reward for a batch so far: 15.0
# Training Loss: 0.014966702088713646
# ==========================================
# Epoch:  155 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -4.0
# Mean Reward of that batch -1.0
# Average Reward of all training: 0.6593548387096775
# Max reward for a batch so far: 15.0
# Training Loss: -0.005959827918559313
# ==========================================
# Epoch:  156 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -4.0
# Mean Reward of that batch -1.0
# Average Reward of all training: 0.6487179487179487
# Max reward for a batch so far: 15.0
# Training Loss: -0.02127617597579956
# ==========================================
# Epoch:  157 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -3.0
# Mean Reward of that batch -0.75
# Average Reward of all training: 0.6398089171974523
# Max reward for a batch so far: 15.0
# Training Loss: -0.015174868516623974
# ==========================================
# Epoch:  158 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 0.6463080168776372
# Max reward for a batch so far: 15.0
# Training Loss: -0.00951246079057455
# ==========================================
# Epoch:  159 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 0.6611111111111112
# Max reward for a batch so far: 15.0
# Training Loss: -0.011541160754859447
# ==========================================
# Epoch:  160 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.6569791666666667
# Max reward for a batch so far: 15.0
# Training Loss: 0.009687410667538643
# Model saved
# ==========================================
# Epoch:  161 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -3.0
# Mean Reward of that batch -0.75
# Average Reward of all training: 0.6482401656314699
# Max reward for a batch so far: 15.0
# Training Loss: -0.0185493603348732
# ==========================================
# Epoch:  162 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 0.6457818930041151
# Max reward for a batch so far: 15.0
# Training Loss: -0.027383262291550636
# ==========================================
# Epoch:  163 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -3.0
# Mean Reward of that batch -0.75
# Average Reward of all training: 0.6372188139059304
# Max reward for a batch so far: 15.0
# Training Loss: -0.032337747514247894
# ==========================================
# Epoch:  164 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 0.6373983739837398
# Max reward for a batch so far: 15.0
# Training Loss: -0.026630699634552002
# ==========================================
# Epoch:  165 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 0.6375757575757576
# Max reward for a batch so far: 15.0
# Training Loss: -0.05856144428253174
# ==========================================
# Epoch:  166 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 0.6437751004016065
# Max reward for a batch so far: 15.0
# Training Loss: -0.010463545098900795
# ==========================================
# Epoch:  167 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -1.0
# Mean Reward of that batch -0.25
# Average Reward of all training: 0.6384231536926148
# Max reward for a batch so far: 15.0
# Training Loss: -0.09018728137016296
# ==========================================
# Epoch:  168 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 0.6405753968253968
# Max reward for a batch so far: 15.0
# Training Loss: 0.0168552678078413
# ==========================================
# Epoch:  169 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 0.6505917159763313
# Max reward for a batch so far: 15.0
# Training Loss: -0.00963347777724266
# ==========================================
# Epoch:  170 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 4.0
# Mean Reward of that batch 1.3333333333333333
# Average Reward of all training: 0.6546078431372548
# Max reward for a batch so far: 15.0
# Training Loss: -0.02629995159804821
# Model saved
# ==========================================
# Epoch:  171 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 0.6566276803118908
# ...
# ==========================================
# Epoch:  197 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 0.6444162436548224
# Max reward for a batch so far: 15.0
# Training Loss: -0.1847326010465622
# ==========================================
# Epoch:  198 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 3.0
# Mean Reward of that batch 0.75
# Average Reward of all training: 0.644949494949495
# Max reward for a batch so far: 15.0
# Training Loss: 0.012902995571494102
# ==========================================
# Epoch:  199 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -2.0
# Mean Reward of that batch -0.5
# Average Reward of all training: 0.6391959798994976
# Max reward for a batch so far: 15.0
# Training Loss: -0.08721569180488586
# ==========================================
# Epoch:  200 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 0.6443333333333334
# Max reward for a batch so far: 15.0
# Training Loss: 0.0491601787507534
# Model saved
# ==========================================
# Epoch:  201 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -4.0
# Mean Reward of that batch -1.0
# Average Reward of all training: 0.6361525704809288
# Max reward for a batch so far: 15.0
# Training Loss: -0.1670481115579605
# ==========================================
# Epoch:  202 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -4.0
# Mean Reward of that batch -1.0
# Average Reward of all training: 0.6280528052805281
# Max reward for a batch so far: 15.0
# Training Loss: -0.11821778118610382
# ==========================================
# Epoch:  203 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -4.0
# Mean Reward of that batch -1.0
# Average Reward of all training: 0.620032840722496
# Max reward for a batch so far: 15.0
# Training Loss: -0.06143258884549141
# ==========================================
# Epoch:  204 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -3.0
# Mean Reward of that batch -0.75
# Average Reward of all training: 0.6133169934640523
# Max reward for a batch so far: 15.0
# Training Loss: -0.12284042686223984
# ==========================================
# Epoch:  205 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -4.0
# Mean Reward of that batch -1.0
# Average Reward of all training: 0.6054471544715447
# Max reward for a batch so far: 15.0
# Training Loss: -0.14504322409629822
# ==========================================
# Epoch:  206 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -3.0
# Mean Reward of that batch -0.75
# Average Reward of all training: 0.5988673139158577
# Max reward for a batch so far: 15.0
# Training Loss: -0.057918939739465714
# ==========================================
# Epoch:  207 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 0.5991948470209341
# Max reward for a batch so far: 15.0
# Training Loss: -0.08246398717164993
# ==========================================
# Epoch:  208 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 0.5995192307692307
# Max reward for a batch so far: 15.0
# Training Loss: 0.001898234710097313
# ==========================================
# Epoch:  209 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 1.0
# Mean Reward of that batch 0.3333333333333333
# Average Reward of all training: 0.5982456140350877
# Max reward for a batch so far: 15.0
# Training Loss: -0.06314089149236679
# ==========================================
# Epoch:  210 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 0.6033333333333333
# Max reward for a batch so far: 15.0
# Training Loss: -0.04604598507285118
# Model saved
# ==========================================
# Epoch:  211 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 0.6052132701421801
# Max reward for a batch so far: 15.0
# Training Loss: -0.07977776974439621
# ==========================================
# Epoch:  212 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 0.6102201257861636
# Max reward for a batch so far: 15.0
# Training Loss: -0.011877554468810558
# ==========================================
# Epoch:  213 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 0.6104851330203442
# Max reward for a batch so far: 15.0
# Training Loss: -0.008688904345035553
# ==========================================
# Epoch:  214 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 0.6088006230529595
# Max reward for a batch so far: 15.0
# Training Loss: -0.1443510800600052
# ==========================================
# Epoch:  215 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -1.0
# Mean Reward of that batch -0.25
# Average Reward of all training: 0.6048062015503876
# Max reward for a batch so far: 15.0
# Training Loss: -0.06197405606508255
# ==========================================
# Epoch:  216 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 1.0
# Mean Reward of that batch 0.3333333333333333
# Average Reward of all training: 0.6035493827160494
# Max reward for a batch so far: 15.0
# Training Loss: -0.0496731735765934
# ==========================================
# Epoch:  217 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 0.6053763440860216
# Max reward for a batch so far: 15.0
# Training Loss: -0.21399496495723724
# ==========================================
# Epoch:  218 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 0.6037461773700307
# Max reward for a batch so far: 15.0
# Training Loss: 0.035586558282375336
# ==========================================
# Epoch:  219 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 0.6085996955859969
# Max reward for a batch so far: 15.0
# Training Loss: -0.0023858179338276386
# ==========================================
# Epoch:  220 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -3.0
# Mean Reward of that batch -0.75
# Average Reward of all training: 0.6024242424242424
# Max reward for a batch so far: 15.0
# Training Loss: -0.21808062493801117
# Model saved
# ==========================================
# Epoch:  221 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -2.0
# Mean Reward of that batch -0.5
# Average Reward of all training: 0.5974358974358974
# Max reward for a batch so far: 15.0
# Training Loss: -0.12166279554367065
# ==========================================
# Epoch:  222 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 1.0
# Mean Reward of that batch 0.3333333333333333
# Average Reward of all training: 0.5962462462462462
# Max reward for a batch so far: 15.0
# Training Loss: -0.04489416629076004
# ==========================================
# Epoch:  223 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 0.5980568011958147
# Max reward for a batch so far: 15.0
# Training Loss: 0.0244881734251976
# ==========================================
# Epoch:  224 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -1.0
# Mean Reward of that batch -0.25
# Average Reward of all training: 0.5942708333333332
# Max reward for a batch so far: 15.0
# Training Loss: -0.25204700231552124
# ==========================================
# Epoch:  225 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -1.0
# Mean Reward of that batch -0.25
# Average Reward of all training: 0.5905185185185184
# Max reward for a batch so far: 15.0
# Training Loss: -0.035635434091091156
# ==========================================
# Epoch:  226 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 0.5908554572271386
# Max reward for a batch so far: 15.0
# Training Loss: -0.2118500918149948
# ==========================================
# Epoch:  227 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 1.0
# Mean Reward of that batch 0.3333333333333333
# Average Reward of all training: 0.5897209985315711
# Max reward for a batch so far: 15.0
# Training Loss: 0.0483718179166317
# ==========================================
# Epoch:  228 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 3.0
# Mean Reward of that batch 0.75
# Average Reward of all training: 0.590423976608187
# Max reward for a batch so far: 15.0
# Training Loss: -0.07529270648956299
# ==========================================
# Epoch:  229 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 0.5951237263464337
# Max reward for a batch so far: 15.0
# Training Loss: -0.15342143177986145
# ==========================================
# Epoch:  230 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 1.0
# Mean Reward of that batch 0.3333333333333333
# Average Reward of all training: 0.5939855072463768
# Max reward for a batch so far: 15.0
# Training Loss: -0.02580679953098297
# Model saved
# ==========================================
# Epoch:  231 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 0.5986291486291486
# Max reward for a batch so far: 15.0
# Training Loss: -0.04581388458609581
# ==========================================
# Epoch:  232 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 1.0
# Mean Reward of that batch 0.3333333333333333
# Average Reward of all training: 0.5974856321839079
# Max reward for a batch so far: 15.0
# Training Loss: -0.17839829623699188
# ==========================================
# Epoch:  233 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 0.6020743919885551
# Max reward for a batch so far: 15.0
# Training Loss: -0.04674747958779335
# ==========================================
# Epoch:  234 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 0.6037749287749288
# Max reward for a batch so far: 15.0
# Training Loss: -0.1783030480146408
# ==========================================
# Epoch:  235 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 0.6022695035460993
# Max reward for a batch so far: 15.0
# Training Loss: -0.17339640855789185
# ==========================================
# Epoch:  236 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 0.603954802259887
# Max reward for a batch so far: 15.0
# Training Loss: 0.02118377760052681
# ==========================================
# Epoch:  237 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 0.609845288326301
# Max reward for a batch so far: 15.0
# Training Loss: -0.10861261934041977
# ==========================================
# Epoch:  238 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -1.0
# Mean Reward of that batch -0.25
# Average Reward of all training: 0.6062324929971988
# Max reward for a batch so far: 15.0
# Training Loss: -0.12920932471752167
# ==========================================
# Epoch:  239 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -3.0
# Mean Reward of that batch -0.75
# Average Reward of all training: 0.600557880055788
# Max reward for a batch so far: 15.0
# Training Loss: 0.01552665326744318
# ==========================================
# Epoch:  240 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -1.0
# Mean Reward of that batch -0.25
# Average Reward of all training: 0.5970138888888888
# Max reward for a batch so far: 15.0
# Training Loss: -0.13311122357845306
# Model saved
# ==========================================
# Epoch:  241 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 0.594536652835408
# Max reward for a batch so far: 15.0
# Training Loss: 0.08705959469079971
# ==========================================
# Epoch:  242 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -4.0
# Mean Reward of that batch -1.0
# Average Reward of all training: 0.5879476584022039
# Max reward for a batch so far: 15.0
# Training Loss: -0.24253222346305847
# ==========================================
# Epoch:  243 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 0.5882716049382716
# Max reward for a batch so far: 15.0
# Training Loss: 0.25342732667922974
# ==========================================
# Epoch:  244 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -4.0
# Mean Reward of that batch -1.0
# Average Reward of all training: 0.5817622950819672
# Max reward for a batch so far: 15.0
# Training Loss: -0.45875340700149536
# ==========================================
# Epoch:  245 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -2.0
# Mean Reward of that batch -0.5
# Average Reward of all training: 0.5773469387755101
# Max reward for a batch so far: 15.0
# Training Loss: -0.31181600689888
# ==========================================
# Epoch:  246 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -2.0
# Mean Reward of that batch -0.5
# Average Reward of all training: 0.5729674796747967
# Max reward for a batch so far: 15.0
# Training Loss: -0.3119392395019531
# ==========================================
# Epoch:  247 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -3.0
# Mean Reward of that batch -0.75
# Average Reward of all training: 0.5676113360323887
# Max reward for a batch so far: 15.0
# Training Loss: -0.31613364815711975
# ==========================================
# Epoch:  248 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 4.0
# Mean Reward of that batch 1.3333333333333333
# Average Reward of all training: 0.5706989247311828
# Max reward for a batch so far: 15.0
# Training Loss: 0.27014636993408203
# ==========================================
# Epoch:  249 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -1.0
# Mean Reward of that batch -0.25
# Average Reward of all training: 0.5674029451137885
# Max reward for a batch so far: 15.0
# Training Loss: nan
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-95466a340e0a> in <module>
#      17     while epoch < num_epochs + 1:
#      18         # Gather training data
# ---> 19         states_mb, actions_mb, rewards_of_batch, discounted_rewards_mb, nb_episodes_mb = make_batch(batch_size, stacked_frames)
#      20
#      21         ### These part is used for analytics
#
# <ipython-input-13-de26d210871d> in make_batch(batch_size, stacked_frames)
#      25         #30% chance that we take action a2)
#      26         action = np.random.choice(range(action_probability_distribution.shape[1]),
# ---> 27                                   p=action_probability_distribution.ravel())  # select action w.r.t the actions prob
#      28         action = possible_actions[action]
#      29
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: probabilities contain NaN

# %% [markdown]
# ## Step 8: Watch our Agent play 👀
# Now that we trained our agent, we can test it

# %%
# Saver
saver = tf.train.Saver()

with tf.Session() as sess:
    game = DoomGame()

    # Load the correct configuration 
    game.load_config("defend_the_center.cfg")
    
    # Load the correct scenario (in our case basic scenario)
    game.set_doom_scenario_path("defend_the_center.wad")
    
    # Load the model
    saver.restore(sess, "./models/model.ckpt")
    game.init()
    
    for i in range(10):
        
        # Launch a new episode
        game.new_episode()

        # Get a new state
        state = game.get_state().screen_buffer
        state, stacked_frames = stack_frames(stacked_frames, state, True)

        while not game.is_episode_finished():
        
            # Run State Through Policy & Calculate Action
            action_probability_distribution = sess.run(PGNetwork.action_distribution, 
                                                       feed_dict={PGNetwork.inputs_: state.reshape(1, *state_size)})

            # REMEMBER THAT WE ARE IN A STOCHASTIC POLICY SO WE DON'T ALWAYS TAKE THE ACTION WITH THE HIGHEST PROBABILITY
            # (For instance if the action with the best probability for state S is a1 with 70% chances, there is
            #30% chance that we take action a2)
            action = np.random.choice(range(action_probability_distribution.shape[1]), 
                                      p=action_probability_distribution.ravel())  # select action w.r.t the actions prob
            action = possible_actions[action]

            # Perform action
            reward = game.make_action(action)
            done = game.is_episode_finished()
            
            if done:
                break
            else:
                # If not done, the next_state become the current state
                next_state = game.get_state().screen_buffer
                next_state, stacked_frames = stack_frames(stacked_frames, next_state, False)
                state = next_state
        

        print("Score for episode ", i, " :", game.get_total_reward())
    game.close()
