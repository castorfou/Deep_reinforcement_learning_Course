# %% [markdown]
# # Doom-Deathmatch: REINFORCE Monte Carlo Policy gradients 🕹️

# %% [markdown]
# In this notebook we'll implement an agent <b>that try to survive in Doom environment by killing all monster that are spawned in the map.</b> <br>
# Our agent playing after 206 epochs of 1000 batch_size (2h of training with CPU), **we can see that our agent needs much more training but he begins to have rational actions.**
# <img src="assets/doom.gif" alt="Doom Deathmatch" />

# %% [markdown]
# # This is a notebook from [Deep Reinforcement Learning Course with Tensorflow](https://simoninithomas.github.io/Deep_reinforcement_learning_Course/)
# <img src="https://raw.githubusercontent.com/simoninithomas/Deep_reinforcement_learning_Course/master/docs/assets/img/DRLC%20Environments.png" alt="Deep Reinforcement Course"/>
# <br>
# <p>  Deep Reinforcement Learning Course is a free series of articles and videos tutorials 🆕 about Deep Reinforcement Learning, where **we'll learn the main algorithms (Q-learning, Deep Q Nets, Dueling Deep Q Nets, Policy Gradients, A2C, Proximal Policy Gradients…), and how to implement them with Tensorflow.**
# <br><br>
#
# 📜The articles explain the architectures from the big picture to the mathematical details behind them.
# <br>
# 📹 The videos explain how to build the agents with Tensorflow </b></p>
# <br>
# This course will give you a **solid foundation for understanding and implementing the future state of the art algorithms**. And, you'll build a strong professional portfolio by creating **agents that learn to play awesome environments**: Doom© 👹, Space invaders 👾, Outrun, Sonic the Hedgehog©, Michael Jackson’s Moonwalker, agents that will be able to navigate in 3D environments with DeepMindLab (Quake) and able to walk with Mujoco.
# <br><br>
# </p>
#
# ## 📚 The complete [Syllabus HERE](https://simoninithomas.github.io/Deep_reinforcement_learning_Course/)
#
#
# ## Any questions 👨‍💻
# <p> If you have any questions, feel free to ask me: </p>
# <p> 📧: <a href="mailto:hello@simoninithomas.com">hello@simoninithomas.com</a>  </p>
# <p> Github: https://github.com/simoninithomas/Deep_reinforcement_learning_Course </p>
# <p> 🌐 : https://simoninithomas.github.io/Deep_reinforcement_learning_Course/ </p>
# <p> Twitter: <a href="https://twitter.com/ThomasSimonini">@ThomasSimonini</a> </p>
# <p> Don't forget to <b> follow me on <a href="https://twitter.com/ThomasSimonini">twitter</a>, <a href="https://github.com/simoninithomas/Deep_reinforcement_learning_Course">github</a> and <a href="https://medium.com/@thomassimonini">Medium</a> to be alerted of the new articles that I publish </b></p>
#
# ## How to help  🙌
# 3 ways:
# - **Clap our articles and like our videos a lot**:Clapping in Medium means that you really like our articles. And the more claps we have, the more our article is shared Liking our videos help them to be much more visible to the deep learning community.
# - **Share and speak about our articles and videos**: By sharing our articles and videos you help us to spread the word.
# - **Improve our notebooks**: if you found a bug or **a better implementation** you can send a pull request.
# <br>
#
# ## Important note 🤔
# <b> You can run it on your computer but it's better to run it on GPU based services</b>, personally I use Microsoft Azure and their Deep Learning Virtual Machine (they offer 170$)
# https://azuremarketplace.microsoft.com/en-us/marketplace/apps/microsoft-ads.dsvm-deep-learning
# <br>
# ⚠️ I don't have any business relations with them. I just loved their excellent customer service.
#
# If you have some troubles to use Microsoft Azure follow the explainations of this excellent article here (without last the part fast.ai): https://medium.com/@manikantayadunanda/setting-up-deeplearning-machine-and-fast-ai-on-azure-a22eb6bd6429

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving on the notebook **you need to understand**:
# - The foundations of Reinforcement learning (MC, TD, Rewards hypothesis...) [Article](https://medium.freecodecamp.org/an-introduction-to-reinforcement-learning-4339519de419)
# - Policy gradients [Article](https://medium.freecodecamp.org/an-introduction-to-policy-gradients-with-cartpole-and-doom-495b5ef2207f)
# - We made a [tutorial video](https://youtu.be/wLTQRuizVyE) where we implement a Policy Gradient agent with Tensorflow that learns to play Doom 👹🔫 in a Deathmatch environment.

# %%
from IPython.display import HTML
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/wLTQRuizVyE?showinfo=0" frameborder="0" allow="autoplay; encrypted-media" allowfullscreen></iframe>')
# Out:
# /home/explore/miniconda3/envs/drl_simonini/lib/python3.7/site-packages/IPython/core/display.py:717: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="560" height="315" src="https://www.youtube.com/embed/wLTQRuizVyE?showinfo=0" frameborder="0" allow="autoplay; encrypted-media" allowfullscreen></iframe>

# %% [markdown]
# ## Step 1: Import the libraries 📚

# %%
import tensorflow as tf      # Deep Learning library
import numpy as np           # Handle matrices
from vizdoom import *        # Doom Environment
import random                # Handling random number generation
import time                  # Handling time calculation
from skimage import transform# Help us to preprocess the frames

from collections import deque# Ordered collection with ends
import matplotlib.pyplot as plt # Display graphs

import warnings # This ignore all the warning messages that are normally printed during the training because of skiimage
warnings.filterwarnings('ignore')

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth=True

# %% [markdown]
# ## Step 2: Create our environment 🎮
# - Now that we imported the libraries/dependencies, we will create our environment.
# - Doom environment takes:
#     - A `configuration file` that **handle all the options** (size of the frame, possible actions...)
#     - A `scenario file`: that **generates the correct scenario** (in our case basic **but you're invited to try other scenarios**).
# - Note: We have 3 possible actions turn left, turn right, shoot (attack) `[[0,0,1], [1,0,0], [0,1,0]]` so we don't need to do one hot encoding (thanks to <a href="https://stackoverflow.com/users/2237916/silgon">silgon</a> for figuring out.
#
# ### Our environment
# <img src="https://simoninithomas.github.io/Deep_reinforcement_learning_Course/assets/img/video%20projects/vizdoomdeathmatch.png" style="max-width:500px;" alt="Doom health"/>
#
# - The purpose of this scenario is **to teach the agent that killing the monsters is GOOD and when monsters kill you is BAD**.
# - In addition, **wasting amunition is not very good either**.
# - Agent is rewarded only for killing monsters so he has to figure out the rest for himself.
# <br><br>
# - Map is a large circle. Player is spawned in the exact center. 5 melee-only, monsters are spawned along the wall.
# - **Monsters are killed after a single shot.**
# - After dying each monster is **respawned after some time**.
# - Episode ends when the player dies (**it's inevitable becuse of limitted ammo**).
# <br><br>
# REWARDS:
# - +1 for killing a monster
# <br><br>
# - 3 available buttons: turn left, turn right, shoot (attack)
# - death penalty = 1

# %%
"""
Here we create our environment
"""
def create_environment():
    game = DoomGame()
    
    # Load the correct configuration
    game.load_config("defend_the_center.cfg")
    
    # Load the correct scenario (in our case defend_the_center scenario)
    game.set_doom_scenario_path("defend_the_center.wad")
    
    game.init()
    
    # Here our possible actions
    # [[1,0,0],[0,1,0],[0,0,1]]
    possible_actions  = np.identity(3,dtype=int).tolist()
    
    return game, possible_actions

# %%
game, possible_actions = create_environment()

# %% [markdown]
# ## Step 3: Define the preprocessing functions ⚙️
# ### preprocess_frame 🖼️
# Preprocessing is an important step, <b>because we want to reduce the complexity of our states to reduce the computation time needed for training.</b>
# <br><br>
# Our steps:
# - Grayscale each of our frames (because <b> color does not add important information </b>). But this is already done by the config file.
# - Crop the screen (in our case we remove the roof because it contains no information)
# - We normalize pixel values
# - Finally we resize the preprocessed frame

# %%
"""
    preprocess_frame:
    Take a frame.
    Resize it.
        __________________
        |                 |
        |                 |
        |                 |
        |                 |
        |_________________|
        
        to
        _____________
        |            |
        |            |
        |            |
        |____________|
    Normalize it.
    
    return preprocessed_frame
    
    """
def preprocess_frame(frame):
    # Greyscale frame already done in our vizdoom config
    # x = np.mean(frame,-1)
    
    # Crop the screen (remove the roof because it contains no information)
    # [Up: Down, Left: right]
    cropped_frame = frame[40:,:]
    
    # Normalize Pixel Values
    normalized_frame = cropped_frame/255.0
    
    # Resize
    preprocessed_frame = transform.resize(normalized_frame, [100,160])
    
    return preprocessed_frame

# %% [markdown]
# ### stack_frames
# 👏 This part was made possible thanks to help of <a href="https://github.com/Miffyli">Anssi</a><br>
#
# As explained in this really <a href="https://danieltakeshi.github.io/2016/11/25/frame-skipping-and-preprocessing-for-deep-q-networks-on-atari-2600-games/">  good article </a> we stack frames.
#
# Stacking frames is really important because it helps us to **give have a sense of motion to our Neural Network.**
#
# - First we preprocess frame
# - Then we append the frame to the deque that automatically **removes the oldest frame**
# - Finally we **build the stacked state**
#
# This is how work stack:
# - For the first frame, we feed 4 frames
# - At each timestep, **we add the new frame to deque and then we stack them to form a new stacked frame**
# - And so on
# <img src="https://raw.githubusercontent.com/simoninithomas/Deep_reinforcement_learning_Course/master/DQN/Space%20Invaders/assets/stack_frames.png" alt="stack">
# - If we're done, **we create a new stack with 4 new frames (because we are in a new episode)**.

# %%
stack_size = 4 # We stack 4 frames

# Initialize deque with zero-images one array for each image
stacked_frames  =  deque([np.zeros((100,160), dtype=np.int) for i in range(stack_size)], maxlen=4) 

def stack_frames(stacked_frames, state, is_new_episode):
    # Preprocess frame
    frame = preprocess_frame(state)
    
    if is_new_episode:
        # Clear our stacked_frames
        stacked_frames = deque([np.zeros((100,160), dtype=np.int) for i in range(stack_size)], maxlen=4)
        
        # Because we're in a new episode, copy the same frame 4x
        stacked_frames.append(frame)
        stacked_frames.append(frame)
        stacked_frames.append(frame)
        stacked_frames.append(frame)
        
        # Stack the frames
        stacked_state = np.stack(stacked_frames, axis=2)

    else:
        # Append frame to deque, automatically removes the oldest frame
        stacked_frames.append(frame)

        # Build the stacked state (first dimension specifies different frames)
        stacked_state = np.stack(stacked_frames, axis=2) 
    
    return stacked_state, stacked_frames

# %% [markdown]
# ### discount_and_normalize_rewards 💰
# This function is important, because we are in a Monte Carlo situation. <br>
#
# We need to **discount the rewards at the end of the episode**. This function takes, the reward discount it, and **then normalize them** (to avoid a big variability in rewards).

# %%
def discount_and_normalize_rewards(episode_rewards):
    discounted_episode_rewards = np.zeros_like(episode_rewards)
    cumulative = 0.0
    for i in reversed(range(len(episode_rewards))):
        cumulative = cumulative * gamma + episode_rewards[i]
        discounted_episode_rewards[i] = cumulative
    
    mean = np.mean(discounted_episode_rewards)
    std = np.std(discounted_episode_rewards)
    discounted_episode_rewards = (discounted_episode_rewards - mean) / (std)

    return discounted_episode_rewards

# %% [markdown]
# ## Step 4: Set up our hyperparameters ⚗️
# In this part we'll set up our different hyperparameters. But when you implement a Neural Network by yourself you will **not implement hyperparamaters at once but progressively**.
#
# - First, you begin by defining the neural networks hyperparameters when you implement the model.
# - Then, you'll add the training hyperparameters when you implement the training algorithm.

# %%
### ENVIRONMENT HYPERPARAMETERS
state_size = [100,160,4] # Our input is a stack of 4 frames hence 100x160x4 (Width, height, channels) 
action_size = game.get_available_buttons_size() # 3 possible actions: turn left, turn right, shoot
stack_size = 4 # Defines how many frames are stacked together

## TRAINING HYPERPARAMETERS
learning_rate = 0.0001 
num_epochs = 5000  # Total epochs for training 

batch_size = 1000 # Each 1 is a timestep (NOT AN EPISODE) # YOU CAN CHANGE TO 5000 if you have GPU
gamma = 0.99 # Discounting rate

### MODIFY THIS TO FALSE IF YOU JUST WANT TO SEE THE TRAINED AGENT
training = True

# %% [markdown]
# Quick note: Policy gradient methods like reinforce **are on-policy method which can not be updated from experience replay.**

# %% [markdown]
# ## Step 5: Create our Policy Gradient Neural Network model 🧠
#
# This is our Policy Gradient model:
# - We take a stack of 4 frames as input
# - It passes through 3 convnets
# - Then it is flatened
# - Finally it passes through 2 FC layers
# - It outputs a probability distribution over actions

# %% [markdown]
# <img src="assets/doomPG1.png" alt="Doom PG"/>

# %%
class PGNetwork:
    def __init__(self, state_size, action_size, learning_rate, name='PGNetwork'):
        self.state_size = state_size
        self.action_size = action_size
        self.learning_rate = learning_rate
        
        with tf.variable_scope(name):
            with tf.name_scope("inputs"):
                # We create the placeholders
                # *state_size means that we take each elements of state_size in tuple hence is like if we wrote
                # [None, 84, 84, 4]
                self.inputs_= tf.placeholder(tf.float32, [None, *state_size], name="inputs_")
                self.actions = tf.placeholder(tf.int32, [None, action_size], name="actions")
                self.discounted_episode_rewards_ = tf.placeholder(tf.float32, [None, ], name="discounted_episode_rewards_")
            
                
                # Add this placeholder for having this variable in tensorboard
                self.mean_reward_ = tf.placeholder(tf.float32, name="mean_reward")
                
            with tf.name_scope("conv1"):
                """
                First convnet:
                CNN
                BatchNormalization
                ELU
                """
                # Input is 84x84x4
                self.conv1 = tf.layers.conv2d(inputs = self.inputs_,
                                             filters = 32,
                                             kernel_size = [8,8],
                                             strides = [4,4],
                                             padding = "VALID",
                                              kernel_initializer=tf.contrib.layers.xavier_initializer_conv2d(),
                                             name = "conv1")

                self.conv1_batchnorm = tf.layers.batch_normalization(self.conv1,
                                                       training = True,
                                                       epsilon = 1e-5,
                                                         name = 'batch_norm1')

                self.conv1_out = tf.nn.elu(self.conv1_batchnorm, name="conv1_out")
                ## --> [20, 20, 32]
            
            with tf.name_scope("conv2"):
                """
                Second convnet:
                CNN
                BatchNormalization
                ELU
                """
                self.conv2 = tf.layers.conv2d(inputs = self.conv1_out,
                                     filters = 64,
                                     kernel_size = [4,4],
                                     strides = [2,2],
                                     padding = "VALID",
                                    kernel_initializer=tf.contrib.layers.xavier_initializer_conv2d(),
                                     name = "conv2")

                self.conv2_batchnorm = tf.layers.batch_normalization(self.conv2,
                                                       training = True,
                                                       epsilon = 1e-5,
                                                         name = 'batch_norm2')

                self.conv2_out = tf.nn.elu(self.conv2_batchnorm, name="conv2_out")
                ## --> [9, 9, 64]
            
            with tf.name_scope("conv3"):
                """
                Third convnet:
                CNN
                BatchNormalization
                ELU
                """
                self.conv3 = tf.layers.conv2d(inputs = self.conv2_out,
                                     filters = 128,
                                     kernel_size = [4,4],
                                     strides = [2,2],
                                     padding = "VALID",
                                    kernel_initializer=tf.contrib.layers.xavier_initializer_conv2d(),
                                     name = "conv3")

                self.conv3_batchnorm = tf.layers.batch_normalization(self.conv3,
                                                       training = True,
                                                       epsilon = 1e-5,
                                                         name = 'batch_norm3')

                self.conv3_out = tf.nn.elu(self.conv3_batchnorm, name="conv3_out")
                ## --> [3, 3, 128]
            
            with tf.name_scope("flatten"):
                self.flatten = tf.layers.flatten(self.conv3_out)
                ## --> [1152]
            
            with tf.name_scope("fc1"):
                self.fc = tf.layers.dense(inputs = self.flatten,
                                      units = 512,
                                      activation = tf.nn.elu,
                                           kernel_initializer=tf.contrib.layers.xavier_initializer(),
                                    name="fc1")
            
            with tf.name_scope("logits"):
                self.logits = tf.layers.dense(inputs = self.fc, 
                                               kernel_initializer=tf.contrib.layers.xavier_initializer(),
                                              units = 3, 
                                            activation=None)
            
            with tf.name_scope("softmax"):
                self.action_distribution = tf.nn.softmax(self.logits)
                

            with tf.name_scope("loss"):
                # tf.nn.softmax_cross_entropy_with_logits computes the cross entropy of the result after applying the softmax function
                # If you have single-class labels, where an object can only belong to one class, you might now consider using 
                # tf.nn.sparse_softmax_cross_entropy_with_logits so that you don't have to convert your labels to a dense one-hot array. 
                self.neg_log_prob = tf.nn.softmax_cross_entropy_with_logits_v2(logits = self.logits, labels = self.actions)
                self.loss = tf.reduce_mean(self.neg_log_prob * self.discounted_episode_rewards_) 
        
    
            with tf.name_scope("train"):
                self.train_opt = tf.train.RMSPropOptimizer(self.learning_rate).minimize(self.loss)

# %%
# Reset the graph
tf.reset_default_graph()

# Instantiate the PGNetwork
PGNetwork = PGNetwork(state_size, action_size, learning_rate)

# Initialize Session
# sess = tf.Session()
sess = tf.Session(config=config)
init = tf.global_variables_initializer()
sess.run(init)
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From <ipython-input-10-6c75c112285e>:34: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From /home/explore/miniconda3/envs/drl_simonini/lib/python3.7/site-packages/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From <ipython-input-10-6c75c112285e>:39: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.BatchNormalization instead.  In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.batch_normalization` documentation).
# WARNING:tensorflow:From <ipython-input-10-6c75c112285e>:91: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From <ipython-input-10-6c75c112285e>:99: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /home/explore/miniconda3/envs/drl_simonini/lib/python3.7/site-packages/tensorflow_core/python/training/rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %% [markdown]
# ## Step 6: Set up Tensorboard 📊
# For more information about tensorboard, please watch this <a href="https://www.youtube.com/embed/eBbEDRsCmv4">excellent 30min tutorial</a> <br><br>
# To launch tensorboard : `tensorboard --logdir=./tensorboard/policy_gradients/1`

# %%
# Setup TensorBoard Writer
writer = tf.summary.FileWriter("./tensorboard/policy_gradients/1")

## Losses
tf.summary.scalar("Loss", PGNetwork.loss)

## Reward mean
tf.summary.scalar("Reward_mean", PGNetwork.mean_reward_ )

write_op = tf.summary.merge_all()

# %% [markdown]
# ## Step 7: Train our Agent 🏃‍♂️

# %% [markdown]
# Here we'll create batches.<br>
# These batches contains episodes **(their number depends on how many rewards we collect**: for instance if we have episodes with only 10 rewards we can put batch_size/10 episodes
# <br>
# * Make a batch
#     * For each step:
#         * Choose action a
#         * Perform action a
#         * Store s, a, r
#         * **If** done:
#             * Calculate sum reward
#             * Calculate gamma Gt

# %%
def make_batch(batch_size, stacked_frames):
    # Initialize lists: states, actions, rewards_of_episode, rewards_of_batch, discounted_rewards
    states, actions, rewards_of_episode, rewards_of_batch, discounted_rewards = [], [], [], [], []
    
    # Reward of batch is also a trick to keep track of how many timestep we made.
    # We use to to verify at the end of each episode if > batch_size or not.
    
    # Keep track of how many episodes in our batch (useful when we'll need to calculate the average reward per episode)
    episode_num  = 1
    
    # Launch a new episode
    game.new_episode()
        
    # Get a new state
    state = game.get_state().screen_buffer
    state, stacked_frames = stack_frames(stacked_frames, state, True)

    while True:
        # Run State Through Policy & Calculate Action
        action_probability_distribution = sess.run(PGNetwork.action_distribution, 
                                                   feed_dict={PGNetwork.inputs_: state.reshape(1, *state_size)})
        
        # REMEMBER THAT WE ARE IN A STOCHASTIC POLICY SO WE DON'T ALWAYS TAKE THE ACTION WITH THE HIGHEST PROBABILITY
        # (For instance if the action with the best probability for state S is a1 with 70% chances, there is
        #30% chance that we take action a2)
        action = np.random.choice(range(action_probability_distribution.shape[1]), 
                                  p=action_probability_distribution.ravel())  # select action w.r.t the actions prob
        action = possible_actions[action]

        # Perform action
        reward = game.make_action(action)
        done = game.is_episode_finished()

        # Store results
        states.append(state)
        actions.append(action)
        rewards_of_episode.append(reward)
        
        if done:
            # The episode ends so no next state
            next_state = np.zeros((100, 160), dtype=np.int)
            next_state, stacked_frames = stack_frames(stacked_frames, next_state, False)
            
            # Append the rewards_of_batch to reward_of_episode
            rewards_of_batch.append(rewards_of_episode)
            
            # Calculate gamma Gt
            discounted_rewards.append(discount_and_normalize_rewards(rewards_of_episode))
           
            # If the number of rewards_of_batch > batch_size stop the minibatch creation
            # (Because we have sufficient number of episode mb)
            # Remember that we put this condition here, because we want entire episode (Monte Carlo)
            # so we can't check that condition for each step but only if an episode is finished
            if len(np.concatenate(rewards_of_batch)) > batch_size:
                break
                
            # Reset the transition stores
            rewards_of_episode = []
            
            # Add episode
            episode_num += 1
            
            # Start a new episode
            game.new_episode()

            # First we need a state
            state = game.get_state().screen_buffer

            # Stack the frames
            state, stacked_frames = stack_frames(stacked_frames, state, True)
         
        else:
            # If not done, the next_state become the current state
            next_state = game.get_state().screen_buffer
            next_state, stacked_frames = stack_frames(stacked_frames, next_state, False)
            state = next_state
                         
    return np.stack(np.array(states)), np.stack(np.array(actions)), np.concatenate(rewards_of_batch), np.concatenate(discounted_rewards), episode_num

# %% [markdown]
# * Create the Neural Network
# * Initialize the weights
# * Init the environment
# * maxReward = 0 # Keep track of maximum reward
# * **For** epochs in range(num_epochs):
#     * Get batches
#     * Optimize

# %%
# Keep track of all rewards total for each batch
allRewards = []

total_rewards = 0
maximumRewardRecorded = 0
mean_reward_total = []
epoch = 1
average_reward = []

# Saver
saver = tf.train.Saver()

if training:
    # Load the model
    #saver.restore(sess, "./models/model.ckpt")

    while epoch < num_epochs + 1:
        # Gather training data
        states_mb, actions_mb, rewards_of_batch, discounted_rewards_mb, nb_episodes_mb = make_batch(batch_size, stacked_frames)

        ### These part is used for analytics
        # Calculate the total reward ot the batch
        total_reward_of_that_batch = np.sum(rewards_of_batch)
        allRewards.append(total_reward_of_that_batch)

        # Calculate the mean reward of the batch
        # Total rewards of batch / nb episodes in that batch
        mean_reward_of_that_batch = np.divide(total_reward_of_that_batch, nb_episodes_mb)
        mean_reward_total.append(mean_reward_of_that_batch)

        # Calculate the average reward of all training
        # mean_reward_of_that_batch / epoch
        average_reward_of_all_training = np.divide(np.sum(mean_reward_total), epoch)

        # Calculate maximum reward recorded 
        maximumRewardRecorded = np.amax(allRewards)

        print("==========================================")
        print("Epoch: ", epoch, "/", num_epochs)
        print("-----------")
        print("Number of training episodes: {}".format(nb_episodes_mb))
        print("Total reward: {}".format(total_reward_of_that_batch, nb_episodes_mb))
        print("Mean Reward of that batch {}".format(mean_reward_of_that_batch))
        print("Average Reward of all training: {}".format(average_reward_of_all_training))
        print("Max reward for a batch so far: {}".format(maximumRewardRecorded))

        # Feedforward, gradient and backpropagation
        loss_, _ = sess.run([PGNetwork.loss, PGNetwork.train_opt], feed_dict={PGNetwork.inputs_: states_mb.reshape((len(states_mb), 100,160,4)),
                                                            PGNetwork.actions: actions_mb,
                                                                     PGNetwork.discounted_episode_rewards_: discounted_rewards_mb 
                                                                    })

        print("Training Loss: {}".format(loss_))

        # Write TF Summaries
        summary = sess.run(write_op, feed_dict={PGNetwork.inputs_: states_mb.reshape((len(states_mb), 100,160,4)),
                                                            PGNetwork.actions: actions_mb,
                                                                     PGNetwork.discounted_episode_rewards_: discounted_rewards_mb,
                                                                    PGNetwork.mean_reward_: mean_reward_of_that_batch
                                                                    })

        #summary = sess.run(write_op, feed_dict={x: s_.reshape(len(s_),84,84,1), y:a_, d_r: d_r_, r: r_, n: n_})
        writer.add_summary(summary, epoch)
        writer.flush()

        # Save Model
        if epoch % 10 == 0:
            saver.save(sess, "./models/model.ckpt")
            print("Model saved")
        epoch += 1
# Out:
# ==========================================
# Epoch:  1 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.0
# Max reward for a batch so far: 6.0
# Training Loss: 0.04251175746321678
# ==========================================
# Epoch:  2 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 2.333333333333333
# Max reward for a batch so far: 8.0
# Training Loss: -0.02644987963140011
# ==========================================
# Epoch:  3 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.3333333333333335
# Max reward for a batch so far: 8.0
# Training Loss: -0.03318895027041435
# ==========================================
# Epoch:  4 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 2.4166666666666665
# Max reward for a batch so far: 8.0
# Training Loss: 0.007810251787304878
# ==========================================
# Epoch:  5 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.4
# Max reward for a batch so far: 8.0
# Training Loss: -0.0031853425316512585
# ==========================================
# Epoch:  6 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 8.0
# Mean Reward of that batch 4.0
# Average Reward of all training: 2.6666666666666665
# Max reward for a batch so far: 8.0
# Training Loss: 0.012677447870373726
# ==========================================
# Epoch:  7 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.7142857142857144
# Max reward for a batch so far: 9.0
# Training Loss: 0.006448489148169756
# ==========================================
# Epoch:  8 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 2.583333333333333
# Max reward for a batch so far: 9.0
# Training Loss: -0.02488834597170353
# ==========================================
# Epoch:  9 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 2.407407407407407
# Max reward for a batch so far: 9.0
# Training Loss: -0.023311905562877655
# ==========================================
# Epoch:  10 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 4.0
# Mean Reward of that batch 1.3333333333333333
# Average Reward of all training: 2.3
# Max reward for a batch so far: 9.0
# Training Loss: -0.026746446266770363
# Model saved
# ==========================================
# Epoch:  11 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 2.242424242424242
# Max reward for a batch so far: 9.0
# Training Loss: 0.013234797865152359
# ==========================================
# Epoch:  12 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 10.0
# Mean Reward of that batch 5.0
# Average Reward of all training: 2.472222222222222
# Max reward for a batch so far: 10.0
# Training Loss: 0.019087087363004684
# ==========================================
# Epoch:  13 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 2.333333333333333
# Max reward for a batch so far: 10.0
# Training Loss: -0.04245473071932793
# ==========================================
# Epoch:  14 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 2.357142857142857
# Max reward for a batch so far: 10.0
# Training Loss: -0.01728765480220318
# ==========================================
# Epoch:  15 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.3333333333333335
# Max reward for a batch so far: 10.0
# Training Loss: 0.005723648704588413
# ==========================================
# Epoch:  16 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 2.25
# Max reward for a batch so far: 10.0
# Training Loss: -0.029270382598042488
# ==========================================
# Epoch:  17 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 9.0
# Mean Reward of that batch 4.5
# Average Reward of all training: 2.3823529411764706
# Max reward for a batch so far: 10.0
# Training Loss: -0.02129426784813404
# ==========================================
# Epoch:  18 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 2.3055555555555554
# Max reward for a batch so far: 10.0
# Training Loss: -0.0672142431139946
# ==========================================
# Epoch:  19 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 2.324561403508772
# Max reward for a batch so far: 10.0
# Training Loss: 0.006251803599298
# ==========================================
# Epoch:  20 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 2.3416666666666663
# Max reward for a batch so far: 10.0
# Training Loss: -0.021589502692222595
# Model saved
# ==========================================
# Epoch:  21 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 2.2777777777777777
# Max reward for a batch so far: 10.0
# Training Loss: -0.028061380609869957
# ==========================================
# Epoch:  22 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 4.0
# Mean Reward of that batch 1.3333333333333333
# Average Reward of all training: 2.234848484848485
# Max reward for a batch so far: 10.0
# Training Loss: -0.026726190000772476
# ==========================================
# Epoch:  23 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 13.0
# Mean Reward of that batch 4.333333333333333
# Average Reward of all training: 2.3260869565217392
# Max reward for a batch so far: 13.0
# Training Loss: -0.0071959239430725574
# ==========================================
# Epoch:  24 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 2.3402777777777777
# Max reward for a batch so far: 13.0
# Training Loss: -0.01038536336272955
# ==========================================
# Epoch:  25 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 15.0
# Mean Reward of that batch 5.0
# Average Reward of all training: 2.4466666666666668
# Max reward for a batch so far: 15.0
# Training Loss: -0.023100998252630234
# ==========================================
# Epoch:  26 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 2.391025641025641
# Max reward for a batch so far: 15.0
# Training Loss: -0.02156267873942852
# ==========================================
# Epoch:  27 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.41358024691358
# Max reward for a batch so far: 15.0
# Training Loss: -0.05766112729907036
# ==========================================
# Epoch:  28 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 4.0
# Mean Reward of that batch 1.3333333333333333
# Average Reward of all training: 2.3749999999999996
# Max reward for a batch so far: 15.0
# Training Loss: -0.04486333206295967
# ==========================================
# Epoch:  29 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 11.0
# Mean Reward of that batch 3.6666666666666665
# Average Reward of all training: 2.4195402298850572
# Max reward for a batch so far: 15.0
# Training Loss: -0.028063273057341576
# ==========================================
# Epoch:  30 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.416666666666666
# Max reward for a batch so far: 15.0
# Training Loss: -0.013984871096909046
# Model saved
# ==========================================
# Epoch:  31 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.4032258064516125
# Max reward for a batch so far: 15.0
# Training Loss: -0.02242354303598404
# ==========================================
# Epoch:  32 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 10.0
# Mean Reward of that batch 5.0
# Average Reward of all training: 2.484375
# Max reward for a batch so far: 15.0
# Training Loss: -0.009140652604401112
# ==========================================
# Epoch:  33 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 2.45959595959596
# Max reward for a batch so far: 15.0
# Training Loss: -0.024644576013088226
# ==========================================
# Epoch:  34 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.4754901960784315
# Max reward for a batch so far: 15.0
# Training Loss: -0.026427868753671646
# ==========================================
# Epoch:  35 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.4904761904761905
# Max reward for a batch so far: 15.0
# Training Loss: -0.016187170520424843
# ==========================================
# Epoch:  36 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.486111111111111
# Max reward for a batch so far: 15.0
# Training Loss: -0.0017281330656260252
# ==========================================
# Epoch:  37 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 12.0
# Mean Reward of that batch 6.0
# Average Reward of all training: 2.581081081081081
# Max reward for a batch so far: 15.0
# Training Loss: 0.002031796844676137
# ==========================================
# Epoch:  38 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 12.0
# Mean Reward of that batch 6.0
# Average Reward of all training: 2.6710526315789473
# Max reward for a batch so far: 15.0
# Training Loss: -0.020347367972135544
# ==========================================
# Epoch:  39 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 6.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.6794871794871793
# Max reward for a batch so far: 15.0
# Training Loss: -0.044808175414800644
# ==========================================
# Epoch:  40 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 11.0
# Mean Reward of that batch 5.5
# Average Reward of all training: 2.75
# Max reward for a batch so far: 15.0
# Training Loss: 0.00788171123713255
# Model saved
# ==========================================
# Epoch:  41 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 10.0
# Mean Reward of that batch 5.0
# Average Reward of all training: 2.8048780487804876
# Max reward for a batch so far: 15.0
# Training Loss: 0.011180365458130836
# ==========================================
# Epoch:  42 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.7936507936507935
# Max reward for a batch so far: 15.0
# Training Loss: -0.0438956692814827
# ==========================================
# Epoch:  43 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 9.0
# Mean Reward of that batch 4.5
# Average Reward of all training: 2.833333333333333
# Max reward for a batch so far: 15.0
# Training Loss: -0.01767781749367714
# ==========================================
# Epoch:  44 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 11.0
# Mean Reward of that batch 5.5
# Average Reward of all training: 2.893939393939394
# Max reward for a batch so far: 15.0
# Training Loss: -0.047985274344682693
# ==========================================
# Epoch:  45 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.896296296296296
# Max reward for a batch so far: 15.0
# Training Loss: -0.02168053202331066
# ==========================================
# Epoch:  46 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.876811594202898
# Max reward for a batch so far: 15.0
# Training Loss: -0.0447968952357769
# ==========================================
# Epoch:  47 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.8652482269503543
# Max reward for a batch so far: 15.0
# Training Loss: -0.012598016299307346
# ==========================================
# Epoch:  48 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 10.0
# Mean Reward of that batch 3.3333333333333335
# Average Reward of all training: 2.875
# Max reward for a batch so far: 15.0
# Training Loss: -0.009754549711942673
# ==========================================
# Epoch:  49 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 12.0
# Mean Reward of that batch 6.0
# Average Reward of all training: 2.938775510204082
# Max reward for a batch so far: 15.0
# Training Loss: -0.004733105190098286
# ==========================================
# Epoch:  50 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 9.0
# Mean Reward of that batch 4.5
# Average Reward of all training: 2.97
# Max reward for a batch so far: 15.0
# Training Loss: 0.02113805152475834
# Model saved
# ==========================================
# Epoch:  51 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 9.0
# Mean Reward of that batch 4.5
# Average Reward of all training: 3.0
# Max reward for a batch so far: 15.0
# Training Loss: -0.05060930177569389
# ==========================================
# Epoch:  52 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 5.0
# Mean Reward of that batch 1.25
# Average Reward of all training: 2.9663461538461537
# Max reward for a batch so far: 15.0
# Training Loss: -0.016447534784674644
# ==========================================
# Epoch:  53 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.94811320754717
# Max reward for a batch so far: 15.0
# Training Loss: -0.03890571370720863
# ==========================================
# Epoch:  54 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 12.0
# Mean Reward of that batch 4.0
# Average Reward of all training: 2.9675925925925926
# Max reward for a batch so far: 15.0
# Training Loss: -0.01887744478881359
# ==========================================
# Epoch:  55 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.956060606060606
# Max reward for a batch so far: 15.0
# Training Loss: 0.030323119834065437
# ==========================================
# Epoch:  56 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 4.0
# Mean Reward of that batch 1.3333333333333333
# Average Reward of all training: 2.927083333333333
# Max reward for a batch so far: 15.0
# Training Loss: 0.025175685063004494
# ==========================================
# Epoch:  57 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 11.0
# Mean Reward of that batch 3.6666666666666665
# Average Reward of all training: 2.9400584795321634
# Max reward for a batch so far: 15.0
# Training Loss: 0.0021303182002156973
# ==========================================
# Epoch:  58 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 11.0
# Mean Reward of that batch 3.6666666666666665
# Average Reward of all training: 2.952586206896551
# Max reward for a batch so far: 15.0
# Training Loss: 0.003953178878873587
# ==========================================
# Epoch:  59 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 2.9477401129943495
# Max reward for a batch so far: 15.0
# Training Loss: 0.04694316163659096
# ==========================================
# Epoch:  60 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 2.9097222222222214
# Max reward for a batch so far: 15.0
# Training Loss: -0.03391032665967941
# Model saved
# ==========================================
# Epoch:  61 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.8948087431693983
# Max reward for a batch so far: 15.0
# Training Loss: -0.01627405174076557
# ==========================================
# Epoch:  62 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 2.874999999999999
# Max reward for a batch so far: 15.0
# Training Loss: 0.00775486696511507
# ==========================================
# Epoch:  63 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 11.0
# Mean Reward of that batch 3.6666666666666665
# Average Reward of all training: 2.8875661375661363
# Max reward for a batch so far: 15.0
# Training Loss: 0.025732843205332756
# ==========================================
# Epoch:  64 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 2.884114583333333
# Max reward for a batch so far: 15.0
# Training Loss: -0.04775423929095268
# ==========================================
# Epoch:  65 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.8858974358974354
# Max reward for a batch so far: 15.0
# Training Loss: -0.00840154942125082
# ==========================================
# Epoch:  66 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.8724747474747474
# Max reward for a batch so far: 15.0
# Training Loss: 0.011700131930410862
# ==========================================
# Epoch:  67 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.874378109452736
# Max reward for a batch so far: 15.0
# Training Loss: -0.028760338202118874
# ==========================================
# Epoch:  68 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 8.0
# Mean Reward of that batch 4.0
# Average Reward of all training: 2.8909313725490193
# Max reward for a batch so far: 15.0
# Training Loss: -0.017424164339900017
# ==========================================
# Epoch:  69 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 2.873188405797101
# Max reward for a batch so far: 15.0
# Training Loss: -0.041804004460573196
# ==========================================
# Epoch:  70 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 11.0
# Mean Reward of that batch 3.6666666666666665
# Average Reward of all training: 2.884523809523809
# Max reward for a batch so far: 15.0
# Training Loss: -0.0280531607568264
# Model saved
# ==========================================
# Epoch:  71 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 8.0
# Mean Reward of that batch 2.6666666666666665
# Average Reward of all training: 2.881455399061032
# Max reward for a batch so far: 15.0
# Training Loss: 0.017021842300891876
# ==========================================
# Epoch:  72 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.869212962962963
# Max reward for a batch so far: 15.0
# Training Loss: 0.01015939936041832
# ==========================================
# Epoch:  73 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.8618721461187215
# Max reward for a batch so far: 15.0
# Training Loss: -0.023438002914190292
# ==========================================
# Epoch:  74 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 13.0
# Mean Reward of that batch 6.5
# Average Reward of all training: 2.911036036036036
# Max reward for a batch so far: 15.0
# Training Loss: 0.0040785325691103935
# ==========================================
# Epoch:  75 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.9122222222222223
# Max reward for a batch so far: 15.0
# Training Loss: -0.03211713209748268
# ==========================================
# Epoch:  76 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 4.0
# Mean Reward of that batch 1.3333333333333333
# Average Reward of all training: 2.8914473684210527
# Max reward for a batch so far: 15.0
# Training Loss: -0.009099890477955341
# ==========================================
# Epoch:  77 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 4.0
# Mean Reward of that batch 1.3333333333333333
# Average Reward of all training: 2.8712121212121215
# Max reward for a batch so far: 15.0
# Training Loss: -0.034637875854969025
# ==========================================
# Epoch:  78 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.8643162393162394
# Max reward for a batch so far: 15.0
# Training Loss: -0.06571666151285172
# ==========================================
# Epoch:  79 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 10.0
# Mean Reward of that batch 3.3333333333333335
# Average Reward of all training: 2.8702531645569622
# Max reward for a batch so far: 15.0
# Training Loss: -0.037149205803871155
# ==========================================
# Epoch:  80 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 12.0
# Mean Reward of that batch 4.0
# Average Reward of all training: 2.884375
# Max reward for a batch so far: 15.0
# Training Loss: 0.010930427350103855
# Model saved
# ==========================================
# Epoch:  81 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.8858024691358026
# Max reward for a batch so far: 15.0
# Training Loss: -0.016401058062911034
# ==========================================
# Epoch:  82 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 7.0
# Mean Reward of that batch 3.5
# Average Reward of all training: 2.893292682926829
# Max reward for a batch so far: 15.0
# Training Loss: -0.04698764160275459
# ==========================================
# Epoch:  83 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.8825301204819276
# Max reward for a batch so far: 15.0
# Training Loss: -0.07368724048137665
# ==========================================
# Epoch:  84 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 10.0
# Mean Reward of that batch 3.3333333333333335
# Average Reward of all training: 2.8878968253968256
# Max reward for a batch so far: 15.0
# Training Loss: -0.061083998531103134
# ==========================================
# Epoch:  85 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 10.0
# Mean Reward of that batch 3.3333333333333335
# Average Reward of all training: 2.893137254901961
# Max reward for a batch so far: 15.0
# Training Loss: -0.049670569598674774
# ==========================================
# Epoch:  86 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 8.0
# Mean Reward of that batch 4.0
# Average Reward of all training: 2.9060077519379846
# Max reward for a batch so far: 15.0
# Training Loss: -0.054940365254879
# ==========================================
# Epoch:  87 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 5.0
# Mean Reward of that batch 2.5
# Average Reward of all training: 2.9013409961685825
# Max reward for a batch so far: 15.0
# Training Loss: -0.06105206161737442
# ==========================================
# Epoch:  88 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.8948863636363633
# Max reward for a batch so far: 15.0
# Training Loss: -0.0017720876494422555
# ==========================================
# Epoch:  89 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 2.873595505617977
# Max reward for a batch so far: 15.0
# Training Loss: 0.0004463228106033057
# ==========================================
# Epoch:  90 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 10.0
# Mean Reward of that batch 5.0
# Average Reward of all training: 2.897222222222222
# Max reward for a batch so far: 15.0
# Training Loss: -0.013309386558830738
# Model saved
# ==========================================
# Epoch:  91 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 11.0
# Mean Reward of that batch 5.5
# Average Reward of all training: 2.9258241758241756
# Max reward for a batch so far: 15.0
# Training Loss: 0.028286969289183617
# ==========================================
# Epoch:  92 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.9157608695652173
# Max reward for a batch so far: 15.0
# Training Loss: -0.029604081064462662
# ==========================================
# Epoch:  93 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 2.902329749103943
# Max reward for a batch so far: 15.0
# Training Loss: -0.01652457006275654
# ==========================================
# Epoch:  94 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 2.8785460992907805
# Max reward for a batch so far: 15.0
# Training Loss: -0.037125445902347565
# ==========================================
# Epoch:  95 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 2.8587719298245617
# Max reward for a batch so far: 15.0
# Training Loss: -0.010278552770614624
# ==========================================
# Epoch:  96 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 2.8359375
# Max reward for a batch so far: 15.0
# Training Loss: -0.06297024339437485
# ==========================================
# Epoch:  97 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 4.0
# Mean Reward of that batch 1.3333333333333333
# Average Reward of all training: 2.8204467353951888
# Max reward for a batch so far: 15.0
# Training Loss: -0.005071378778666258
# ==========================================
# Epoch:  98 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 2.798469387755102
# Max reward for a batch so far: 15.0
# Training Loss: 0.026543155312538147
# ==========================================
# Epoch:  99 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 4.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.79040404040404
# Max reward for a batch so far: 15.0
# Training Loss: -0.04244840145111084
# ==========================================
# Epoch:  100 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.7925
# Max reward for a batch so far: 15.0
# Training Loss: 0.05164957046508789
# Model saved
# ==========================================
# Epoch:  101 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 1.0
# Mean Reward of that batch 0.3333333333333333
# Average Reward of all training: 2.768151815181518
# Max reward for a batch so far: 15.0
# Training Loss: -0.04034692049026489
# ==========================================
# Epoch:  102 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 1.0
# Mean Reward of that batch 0.3333333333333333
# Average Reward of all training: 2.7442810457516336
# Max reward for a batch so far: 15.0
# Training Loss: -0.08715233206748962
# ==========================================
# Epoch:  103 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 8.0
# Mean Reward of that batch 4.0
# Average Reward of all training: 2.756472491909385
# Max reward for a batch so far: 15.0
# Training Loss: -0.0038689833600074053
# ==========================================
# Epoch:  104 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 11.0
# Mean Reward of that batch 3.6666666666666665
# Average Reward of all training: 2.7652243589743586
# Max reward for a batch so far: 15.0
# Training Loss: -0.022389674559235573
# ==========================================
# Epoch:  105 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 2.7484126984126984
# Max reward for a batch so far: 15.0
# Training Loss: -0.04030377417802811
# ==========================================
# Epoch:  106 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 7.0
# Mean Reward of that batch 3.5
# Average Reward of all training: 2.755503144654088
# Max reward for a batch so far: 15.0
# Training Loss: 0.015023546293377876
# ==========================================
# Epoch:  107 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 2.0
# Mean Reward of that batch 0.5
# Average Reward of all training: 2.7344236760124607
# Max reward for a batch so far: 15.0
# Training Loss: -0.03199975565075874
# ==========================================
# Epoch:  108 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 2.718364197530864
# Max reward for a batch so far: 15.0
# Training Loss: -0.04102492704987526
# ==========================================
# Epoch:  109 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 4.0
# Mean Reward of that batch 1.3333333333333333
# Average Reward of all training: 2.7056574923547396
# Max reward for a batch so far: 15.0
# Training Loss: -0.05442702770233154
# ==========================================
# Epoch:  110 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 12.0
# Mean Reward of that batch 4.0
# Average Reward of all training: 2.7174242424242423
# Max reward for a batch so far: 15.0
# Training Loss: -0.07340561598539352
# Model saved
# ==========================================
# Epoch:  111 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.7109609609609606
# Max reward for a batch so far: 15.0
# Training Loss: -0.09326072037220001
# ==========================================
# Epoch:  112 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 10.0
# Mean Reward of that batch 3.3333333333333335
# Average Reward of all training: 2.716517857142857
# Max reward for a batch so far: 15.0
# Training Loss: 0.014130573719739914
# ==========================================
# Epoch:  113 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 9.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.7190265486725664
# Max reward for a batch so far: 15.0
# Training Loss: -0.05360880866646767
# ==========================================
# Epoch:  114 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 4.0
# Mean Reward of that batch 1.3333333333333333
# Average Reward of all training: 2.7068713450292394
# Max reward for a batch so far: 15.0
# Training Loss: -0.09470849484205246
# ==========================================
# Epoch:  115 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 1.0
# Mean Reward of that batch 0.3333333333333333
# Average Reward of all training: 2.6862318840579706
# Max reward for a batch so far: 15.0
# Training Loss: 0.0024349777959287167
# ==========================================
# Epoch:  116 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 2.677442528735632
# Max reward for a batch so far: 15.0
# Training Loss: -0.0921715646982193
# ==========================================
# Epoch:  117 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 2.6688034188034186
# Max reward for a batch so far: 15.0
# Training Loss: -0.11297356337308884
# ==========================================
# Epoch:  118 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 13.0
# Mean Reward of that batch 6.5
# Average Reward of all training: 2.7012711864406778
# Max reward for a batch so far: 15.0
# Training Loss: 0.08957841247320175
# ==========================================
# Epoch:  119 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 2.692577030812325
# Max reward for a batch so far: 15.0
# Training Loss: -0.04528215155005455
# ==========================================
# Epoch:  120 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.6868055555555554
# Max reward for a batch so far: 15.0
# Training Loss: -0.012245690450072289
# Model saved
# ==========================================
# Epoch:  121 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 2.6701101928374653
# Max reward for a batch so far: 15.0
# Training Loss: 0.004933152347803116
# ==========================================
# Epoch:  122 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -4.0
# Mean Reward of that batch -1.0
# Average Reward of all training: 2.6400273224043715
# Max reward for a batch so far: 15.0
# Training Loss: -0.06724345684051514
# ==========================================
# Epoch:  123 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 4.0
# Mean Reward of that batch 1.3333333333333333
# Average Reward of all training: 2.6294037940379402
# Max reward for a batch so far: 15.0
# Training Loss: -0.019570399075746536
# ==========================================
# Epoch:  124 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 2.6081989247311825
# Max reward for a batch so far: 15.0
# Training Loss: -0.08214594423770905
# ==========================================
# Epoch:  125 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 2.6006666666666667
# Max reward for a batch so far: 15.0
# Training Loss: 0.017847681418061256
# ==========================================
# Epoch:  126 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 1.0
# Mean Reward of that batch 0.3333333333333333
# Average Reward of all training: 2.5826719576719572
# Max reward for a batch so far: 15.0
# Training Loss: 0.006892476696521044
# ==========================================
# Epoch:  127 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -4.0
# Mean Reward of that batch -1.0
# Average Reward of all training: 2.5544619422572175
# Max reward for a batch so far: 15.0
# Training Loss: -0.039645466953516006
# ==========================================
# Epoch:  128 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -1.0
# Mean Reward of that batch -0.25
# Average Reward of all training: 2.532552083333333
# Max reward for a batch so far: 15.0
# Training Loss: -0.0366569422185421
# ==========================================
# Epoch:  129 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 2.5206718346253227
# Max reward for a batch so far: 15.0
# Training Loss: -0.1285097450017929
# ==========================================
# Epoch:  130 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.516666666666666
# Max reward for a batch so far: 15.0
# Training Loss: 0.01872512884438038
# Model saved
# ==========================================
# Epoch:  131 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -3.0
# Mean Reward of that batch -0.75
# Average Reward of all training: 2.4917302798982184
# Max reward for a batch so far: 15.0
# Training Loss: -0.07511579990386963
# ==========================================
# Epoch:  132 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 11.0
# Mean Reward of that batch 3.6666666666666665
# Average Reward of all training: 2.500631313131313
# Max reward for a batch so far: 15.0
# Training Loss: -0.013892784714698792
# ==========================================
# Epoch:  133 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 2.494360902255639
# Max reward for a batch so far: 15.0
# Training Loss: 0.08221926540136337
# ==========================================
# Epoch:  134 / 5000
# -----------
# Number of training episodes: 3
# Total reward: -1.0
# Mean Reward of that batch -0.3333333333333333
# Average Reward of all training: 2.473258706467661
# Max reward for a batch so far: 15.0
# Training Loss: -0.03158901631832123
# ==========================================
# Epoch:  135 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 2.454938271604938
# Max reward for a batch so far: 15.0
# Training Loss: -0.06596006453037262
# ==========================================
# Epoch:  136 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -3.0
# Mean Reward of that batch -0.75
# Average Reward of all training: 2.4313725490196076
# Max reward for a batch so far: 15.0
# Training Loss: -0.08036378026008606
# ==========================================
# Epoch:  137 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.4306569343065694
# Max reward for a batch so far: 15.0
# Training Loss: -0.044171299785375595
# ==========================================
# Epoch:  138 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 4.0
# Mean Reward of that batch 1.3333333333333333
# Average Reward of all training: 2.422705314009662
# Max reward for a batch so far: 15.0
# Training Loss: -0.20439119637012482
# ==========================================
# Epoch:  139 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -4.0
# Mean Reward of that batch -1.0
# Average Reward of all training: 2.3980815347721824
# Max reward for a batch so far: 15.0
# Training Loss: -0.04086294770240784
# ==========================================
# Epoch:  140 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -3.0
# Mean Reward of that batch -0.75
# Average Reward of all training: 2.3755952380952383
# Max reward for a batch so far: 15.0
# Training Loss: -0.076506607234478
# Model saved
# ==========================================
# Epoch:  141 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.3729314420803784
# Max reward for a batch so far: 15.0
# Training Loss: -0.1355615109205246
# ==========================================
# Epoch:  142 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 2.3609154929577465
# Max reward for a batch so far: 15.0
# Training Loss: -0.08053235709667206
# ==========================================
# Epoch:  143 / 5000
# -----------
# Number of training episodes: 2
# Total reward: 6.0
# Mean Reward of that batch 3.0
# Average Reward of all training: 2.3653846153846154
# Max reward for a batch so far: 15.0
# Training Loss: 0.07267703860998154
# ==========================================
# Epoch:  144 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 11.0
# Mean Reward of that batch 3.6666666666666665
# Average Reward of all training: 2.374421296296296
# Max reward for a batch so far: 15.0
# Training Loss: 0.22339466214179993
# ==========================================
# Epoch:  145 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -4.0
# Mean Reward of that batch -1.0
# Average Reward of all training: 2.351149425287356
# Max reward for a batch so far: 15.0
# Training Loss: -0.04725220054388046
# ==========================================
# Epoch:  146 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 2.3396118721461185
# Max reward for a batch so far: 15.0
# Training Loss: -0.05926458165049553
# ==========================================
# Epoch:  147 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -4.0
# Mean Reward of that batch -1.0
# Average Reward of all training: 2.316893424036281
# Max reward for a batch so far: 15.0
# Training Loss: -0.07567194849252701
# ==========================================
# Epoch:  148 / 5000
# -----------
# Number of training episodes: 5
# Total reward: -4.0
# Mean Reward of that batch -0.8
# Average Reward of all training: 2.295833333333333
# Max reward for a batch so far: 15.0
# Training Loss: -0.13301196694374084
# ==========================================
# Epoch:  149 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 1.0
# Mean Reward of that batch 0.3333333333333333
# Average Reward of all training: 2.2826621923937362
# Max reward for a batch so far: 15.0
# Training Loss: 0.07461513578891754
# ==========================================
# Epoch:  150 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 2.2674444444444446
# Max reward for a batch so far: 15.0
# Training Loss: -0.0017284820787608624
# Model saved
# ==========================================
# Epoch:  151 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 2.2590507726269315
# Max reward for a batch so far: 15.0
# Training Loss: -0.007395053748041391
# ==========================================
# Epoch:  152 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.2573464912280703
# Max reward for a batch so far: 15.0
# Training Loss: 0.062125224620103836
# ==========================================
# Epoch:  153 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 2.0
# Mean Reward of that batch 0.5
# Average Reward of all training: 2.2458605664488016
# Max reward for a batch so far: 15.0
# Training Loss: -0.05584330856800079
# ==========================================
# Epoch:  154 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 4.0
# Mean Reward of that batch 1.3333333333333333
# Average Reward of all training: 2.239935064935065
# Max reward for a batch so far: 15.0
# Training Loss: -0.01834319345653057
# ==========================================
# Epoch:  155 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 2.2270967741935483
# Max reward for a batch so far: 15.0
# Training Loss: -0.10541046410799026
# ==========================================
# Epoch:  156 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -3.0
# Mean Reward of that batch -0.75
# Average Reward of all training: 2.2080128205128204
# Max reward for a batch so far: 15.0
# Training Loss: -0.11115927249193192
# ==========================================
# Epoch:  157 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.2088110403397025
# Max reward for a batch so far: 15.0
# Training Loss: 0.03485829010605812
# ==========================================
# Epoch:  158 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 2.1990506329113924
# Max reward for a batch so far: 15.0
# Training Loss: -0.07342890650033951
# ==========================================
# Epoch:  159 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 6.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.1977987421383647
# Max reward for a batch so far: 15.0
# Training Loss: 0.05281431972980499
# ==========================================
# Epoch:  160 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -2.0
# Mean Reward of that batch -0.5
# Average Reward of all training: 2.1809374999999998
# Max reward for a batch so far: 15.0
# Training Loss: -0.07756601274013519
# Model saved
# ==========================================
# Epoch:  161 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 2.1777432712215323
# Max reward for a batch so far: 15.0
# Training Loss: 0.0020912897307425737
# ==========================================
# Epoch:  162 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 2.168415637860082
# Max reward for a batch so far: 15.0
# Training Loss: -0.027425503358244896
# ==========================================
# Epoch:  163 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 8.0
# Mean Reward of that batch 2.0
# Average Reward of all training: 2.1673824130879344
# Max reward for a batch so far: 15.0
# Training Loss: 0.030508320778608322
# ==========================================
# Epoch:  164 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.1683943089430895
# Max reward for a batch so far: 15.0
# Training Loss: -0.060799337923526764
# ==========================================
# Epoch:  165 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.1693939393939394
# Max reward for a batch so far: 15.0
# Training Loss: -0.05289922654628754
# ==========================================
# Epoch:  166 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -2.0
# Mean Reward of that batch -0.5
# Average Reward of all training: 2.153313253012048
# Max reward for a batch so far: 15.0
# Training Loss: -0.10094635933637619
# ==========================================
# Epoch:  167 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 2.144411177644711
# Max reward for a batch so far: 15.0
# Training Loss: -0.10599628835916519
# ==========================================
# Epoch:  168 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 7.0
# Mean Reward of that batch 2.3333333333333335
# Average Reward of all training: 2.1455357142857143
# Max reward for a batch so far: 15.0
# Training Loss: 0.029339561238884926
# ==========================================
# Epoch:  169 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 1.0
# Mean Reward of that batch 0.25
# Average Reward of all training: 2.134319526627219
# Max reward for a batch so far: 15.0
# Training Loss: -0.05249679833650589
# ==========================================
# Epoch:  170 / 5000
# -----------
# Number of training episodes: 3
# Total reward: -1.0
# Mean Reward of that batch -0.3333333333333333
# Average Reward of all training: 2.1198039215686273
# Max reward for a batch so far: 15.0
# Training Loss: -0.03045230731368065
# Model saved
# ==========================================
# Epoch:  171 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 3.0
# Mean Reward of that batch 1.0
# Average Reward of all training: 2.1132553606237816
# Max reward for a batch so far: 15.0
# Training Loss: 0.07767578214406967
# ==========================================
# Epoch:  172 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -3.0
# Mean Reward of that batch -0.75
# Average Reward of all training: 2.096608527131783
# Max reward for a batch so far: 15.0
# Training Loss: -0.06641629338264465
# ==========================================
# Epoch:  173 / 5000
# -----------
# Number of training episodes: 5
# Total reward: -2.0
# Mean Reward of that batch -0.4
# Average Reward of all training: 2.082177263969171
# Max reward for a batch so far: 15.0
# Training Loss: -0.042371299117803574
# ==========================================
# Epoch:  174 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 1.0
# Mean Reward of that batch 0.3333333333333333
# Average Reward of all training: 2.072126436781609
# Max reward for a batch so far: 15.0
# Training Loss: -0.04123060032725334
# ==========================================
# Epoch:  175 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 4.0
# Mean Reward of that batch 1.3333333333333333
# Average Reward of all training: 2.067904761904762
# Max reward for a batch so far: 15.0
# Training Loss: -0.08002950996160507
# ==========================================
# Epoch:  176 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 4.0
# Mean Reward of that batch 1.3333333333333333
# Average Reward of all training: 2.0637310606060604
# Max reward for a batch so far: 15.0
# Training Loss: 0.01918000914156437
# ==========================================
# Epoch:  177 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -2.0
# Mean Reward of that batch -0.5
# Average Reward of all training: 2.0492467043314497
# Max reward for a batch so far: 15.0
# Training Loss: -0.06113617494702339
# ==========================================
# Epoch:  178 / 5000
# -----------
# Number of training episodes: 5
# Total reward: -5.0
# Mean Reward of that batch -1.0
# Average Reward of all training: 2.032116104868914
# Max reward for a batch so far: 15.0
# Training Loss: -0.07404577732086182
# ==========================================
# Epoch:  179 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 4.0
# Mean Reward of that batch 1.3333333333333333
# Average Reward of all training: 2.028212290502793
# Max reward for a batch so far: 15.0
# Training Loss: 0.023359224200248718
# ==========================================
# Epoch:  180 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 2.0
# Mean Reward of that batch 0.6666666666666666
# Average Reward of all training: 2.020648148148148
# Max reward for a batch so far: 15.0
# Training Loss: -0.12845610082149506
# Model saved
# ==========================================
# Epoch:  181 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 5.0
# Mean Reward of that batch 1.6666666666666667
# Average Reward of all training: 2.0186924493554326
# Max reward for a batch so far: 15.0
# Training Loss: 0.09502582997083664
# ==========================================
# Epoch:  182 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -4.0
# Mean Reward of that batch -1.0
# Average Reward of all training: 2.002106227106227
# Max reward for a batch so far: 15.0
# Training Loss: -0.0020753052085638046
# ==========================================
# Epoch:  183 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -4.0
# Mean Reward of that batch -1.0
# Average Reward of all training: 1.9857012750455374
# Max reward for a batch so far: 15.0
# Training Loss: 0.00015515991253778338
# ==========================================
# Epoch:  184 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -4.0
# Mean Reward of that batch -1.0
# Average Reward of all training: 1.9694746376811594
# Max reward for a batch so far: 15.0
# Training Loss: -0.05548958480358124
# ==========================================
# Epoch:  185 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -4.0
# Mean Reward of that batch -1.0
# Average Reward of all training: 1.9534234234234233
# Max reward for a batch so far: 15.0
# Training Loss: -0.001166876289062202
# ==========================================
# Epoch:  186 / 5000
# -----------
# Number of training episodes: 4
# Total reward: -1.0
# Mean Reward of that batch -0.25
# Average Reward of all training: 1.9415770609318996
# Max reward for a batch so far: 15.0
# Training Loss: 0.001766291563399136
# ==========================================
# Epoch:  187 / 5000
# -----------
# Number of training episodes: 3
# Total reward: 1.0
# Mean Reward of that batch 0.3333333333333333
# Average Reward of all training: 1.932976827094474
# Max reward for a batch so far: 15.0
# Training Loss: -0.048347923904657364
# ==========================================
# Epoch:  188 / 5000
# -----------
# Number of training episodes: 4
# Total reward: 0.0
# Mean Reward of that batch 0.0
# Average Reward of all training: 1.9226950354609929
# Max reward for a batch so far: 15.0
# Training Loss: nan
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-95466a340e0a> in <module>
#      17     while epoch < num_epochs + 1:
#      18         # Gather training data
# ---> 19         states_mb, actions_mb, rewards_of_batch, discounted_rewards_mb, nb_episodes_mb = make_batch(batch_size, stacked_frames)
#      20
#      21         ### These part is used for analytics
#
# <ipython-input-13-de26d210871d> in make_batch(batch_size, stacked_frames)
#      25         #30% chance that we take action a2)
#      26         action = np.random.choice(range(action_probability_distribution.shape[1]),
# ---> 27                                   p=action_probability_distribution.ravel())  # select action w.r.t the actions prob
#      28         action = possible_actions[action]
#      29
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: probabilities contain NaN

# %% [markdown]
# ## Step 8: Watch our Agent play 👀
# Now that we trained our agent, we can test it

# %%
# Saver
saver = tf.train.Saver()

with tf.Session() as sess:
    game = DoomGame()

    # Load the correct configuration 
    game.load_config("defend_the_center.cfg")
    
    # Load the correct scenario (in our case basic scenario)
    game.set_doom_scenario_path("defend_the_center.wad")
    
    # Load the model
    saver.restore(sess, "./models/model.ckpt")
    game.init()
    
    for i in range(10):
        
        # Launch a new episode
        game.new_episode()

        # Get a new state
        state = game.get_state().screen_buffer
        state, stacked_frames = stack_frames(stacked_frames, state, True)

        while not game.is_episode_finished():
        
            # Run State Through Policy & Calculate Action
            action_probability_distribution = sess.run(PGNetwork.action_distribution, 
                                                       feed_dict={PGNetwork.inputs_: state.reshape(1, *state_size)})

            # REMEMBER THAT WE ARE IN A STOCHASTIC POLICY SO WE DON'T ALWAYS TAKE THE ACTION WITH THE HIGHEST PROBABILITY
            # (For instance if the action with the best probability for state S is a1 with 70% chances, there is
            #30% chance that we take action a2)
            action = np.random.choice(range(action_probability_distribution.shape[1]), 
                                      p=action_probability_distribution.ravel())  # select action w.r.t the actions prob
            action = possible_actions[action]

            # Perform action
            reward = game.make_action(action)
            done = game.is_episode_finished()
            
            if done:
                break
            else:
                # If not done, the next_state become the current state
                next_state = game.get_state().screen_buffer
                next_state, stacked_frames = stack_frames(stacked_frames, next_state, False)
                state = next_state
        

        print("Score for episode ", i, " :", game.get_total_reward())
    game.close()
